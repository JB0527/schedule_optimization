# %% [markdown]
# # Pipe 공정 순서배열에 따른 소요시간 최적화 방법론

# %% [markdown]
# 엑셀 데이터를 기반으로 제품 공정의 스케줄 최적화를 위한 Python 알고리즘을 개발하려고 합니다. 엑셀 데이터는 각 제품의 공정 단계(1단계부터 6단계까지)와 해당 단계의 평균 작업 시간을 포함하고 있습니다.
#
# 데이터 구조:
#
# 제품그룹: 제품 그룹을 나타내는 고유 식별자.
# step1 평균 작업 시간(분) ~ step6 평균 작업 시간(분): 각 공정 단계의 평균 작업 시간.
#
# 제품개수: 각 제품 그룹별로 생산해야 할 제품의 수.
#
# 공정 조건:
# 각 제품은 1단계부터 6단계까지 순차적으로 공정을 진행해야 합니다.
# 각 공정 단계는 병렬 처리가 가능하지만, 다음과 같은 기계(호기) 제한이 있습니다:
# 1단계, 2단계, 5단계, 6단계: 각 단계당 1호기.
# 3단계: 3호기.
# 4단계: 4호기.
# 각 호기는 동시에 하나의 제품만을 처리할 수 있습니다.
# 제품의 공정 순서를 최적화하여 총 작업 소요 시간을 최소화하고, 대기 시간을 줄이고자 합니다.
#
# 예시 상황:
# 일부 제품은 1~5단계는 빠르게 완료되지만 6단계가 오래 걸릴 수 있습니다. 이러한 제품을 우선적으로 처리하여 전체 대기 시간을 줄이고자 합니다.
# 예를 들어, 제품 15가 3단계를 빠르게 완료했지만 제품 23이 4단계에서 오래 걸려 다음 단계로 넘어가는 데 지연이 발생할 수 있습니다. 이러한 대기 시간을 최소화하기 위해 제품의 공정 시작 순서를 최적화해야 합니다.
#
# 목표:
# 모든 제품의 공정을 완료했을 때의 총 작업 소요 시간과 최적화된 제품 순서를 도출하는 Python 코드를 작성합니다.

# %%
# Pipe 공정의 자료구조는 모두 queue 구조를 따릅니다.

# %% [markdown]
# ## 데이터 확인
# 1.   Raw 데이터
# 2.   GT값 (휴리스틱라벨링)
# 3.   정규분포에 따른 데이터 필터링
# 4.   our 데이터 전처리 시스템
#
# *   같은 파이프 종류를 그룹별로 함께 작업하는 경우
# *   전체 파이프에 대해 하나하나 따로 작업하는 경우

# %%
import pandas as pd
#1
#file_path = 'pipe_final.xlsx'
#2
#file_path = 'heuristic_data.xlsx'
#3
#file_path = 'filter_pipe_final_241007.xlsx'
#4
#file_path = 'updated_total.xlsx'
#5
file_path = 'updated_total_filter.xlsx'

# %% [markdown]
# ## OR tools 가장 기본

# %%
# !pip install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.11.4210-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting absl-py>=2.0.0 (from ortools)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from ortools) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ortools) (2.2.2)
# Collecting protobuf<5.27,>=5.26.1 (from ortools)
#   Downloading protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from ortools) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)
# Downloading ortools-9.11.4210-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 57.5 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 9.6 MB/s eta 0:00:00
# Downloading protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 20.7 MB/s eta 0:00:00
# Installing collected packages: protobuf, absl-py, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.6 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.26.1 which is incompatible.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.26.1 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.26.1 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.26.1 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.26.1 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.26.1 which is incompatible.
# Successfully installed absl-py-2.1.0 ortools-9.11.4210 protobuf-5.26.1

# %%
"""
# 4,5 데이터에 해당함
for idx, row in df.iterrows():
    product_group = row['제품군']
    processing_times = {
        'step1': int(round(row['step1 최종 작업 시간'] * SCALE)),
        'step2': int(round(row['step2 최종 작업 시간'] * SCALE)),
        'step3': int(round(row['step3 최종 작업 시간'] * SCALE)),
        'step4': int(round(row['step4 최종 작업 시간'] * SCALE)),
        'step5': int(round(row['step5 최종 작업 시간'] * SCALE)),
        'step6': int(round(row['step6 최종 작업 시간'] * SCALE)),
    }
    units.append({
        'unit_id': f"{product_group}",
        'product_group': product_group,
        'processing_times': processing_times,
    })
--------------------------------------------------------------------------------------
# 1,2,3 데이터에 해당함
    for idx, row in df.iterrows():
        product_group = row['제품번호']
        processing_times_dict = {
            'step1': int(round(row['step1 작업 시간(분)'] * SCALE)),
            'step2': int(round(row['step2 작업 시간(분)'] * SCALE)),
            'step3': int(round(row['step3 작업 시간(분)'] * SCALE)),
            'step4': int(round(row['step4 작업 시간(분)'] * SCALE)),
            'step5': int(round(row['step5 작업 시간(분)'] * SCALE)),
            'step6': int(round(row['step6 작업 시간(분)'] * SCALE)),
        }
        units.append({
            'unit_id': f"{product_group}",
            'product_group': product_group,
            'processing_times': processing_times_dict,
        })


"""

# %% [markdown]
# # 1번경우를 고려한 최적화 방법론

# %%
import pandas as pd
from ortools.sat.python import cp_model

# 엑셀 데이터를 읽어옵니다.
df = pd.read_excel(file_path)

# NaN 값이 있는 행을 제거합니다.
df.dropna(inplace=True)

# 제품 데이터를 단위 제품으로 만듭니다.
units = []
# **시간 단위를 정수로 변환하기 위한 스케일링 팩터를 정의합니다.**
SCALE = 1000  # 소수점 이하 3자리까지 표현


for idx, row in df.iterrows():
    product_group = row['제품군']
    processing_times = {
        'step1': int(round(row['step1 최종 작업 시간'] * SCALE)),
        'step2': int(round(row['step2 최종 작업 시간'] * SCALE)),
        'step3': int(round(row['step3 최종 작업 시간'] * SCALE)),
        'step4': int(round(row['step4 최종 작업 시간'] * SCALE)),
        'step5': int(round(row['step5 최종 작업 시간'] * SCALE)),
        'step6': int(round(row['step6 최종 작업 시간'] * SCALE)),
    }
    units.append({
        'unit_id': f"{product_group}",
        'product_group': product_group,
        'processing_times': processing_times,
    })

# 스케줄링 문제를 정의합니다.
model = cp_model.CpModel()

steps = ['step1', 'step2', 'step3', 'step4', 'step5', 'step6']
machines_per_step = {
    'step1': 1,
    'step2': 1,
    'step3': 3,
    'step4': 4,
    'step5': 1,
    'step6': 1,
}

# 각 단위 제품과 단계에 대한 변수들을 정의합니다.
horizon = sum([u['processing_times'][s] for u in units for s in steps])
unit_step_intervals = {}

for unit in units:
    unit_id = unit['unit_id']
    processing_times = unit['processing_times']
    for step in steps:
        duration = int(processing_times[step])
        start_var = model.NewIntVar(0, horizon, f'start_{unit_id}_{step}')
        end_var = model.NewIntVar(0, horizon, f'end_{unit_id}_{step}')
        interval_var = model.NewIntervalVar(start_var, duration, end_var, f'interval_{unit_id}_{step}')
        unit_step_intervals[(unit_id, step)] = interval_var

# 단계별 선행 조건을 추가합니다.
for unit in units:
    unit_id = unit['unit_id']
    for s in range(len(steps) - 1):
        step_current = steps[s]
        step_next = steps[s + 1]
        end_current = unit_step_intervals[(unit_id, step_current)].EndExpr()
        start_next = unit_step_intervals[(unit_id, step_next)].StartExpr()
        model.Add(end_current <= start_next)

# 각 단계의 기계 용량 제약 조건을 추가합니다.
for step in steps:
    intervals = []
    demands = []
    for unit in units:
        unit_id = unit['unit_id']
        intervals.append(unit_step_intervals[(unit_id, step)])
        demands.append(1)
    machine_capacity = machines_per_step[step]
    model.AddCumulative(intervals, demands, machine_capacity)

# 총 작업 시간을 최소화하는 목표를 설정합니다.
makespan = model.NewIntVar(0, horizon, 'makespan')
end_times = []
for unit in units:
    unit_id = unit['unit_id']
    end_times.append(unit_step_intervals[(unit_id, 'step6')].EndExpr())
model.AddMaxEquality(makespan, end_times)
model.Minimize(makespan)

# 모델을 해결합니다.
solver = cp_model.CpSolver()
solver.parameters.max_time_in_seconds = 300.0
status = solver.Solve(model)

# 결과를 출력합니다.
if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
    print(f"총 작업 시간: {solver.ObjectiveValue()} 분")
    schedule = []
    for unit in units:
        unit_id = unit['unit_id']
        unit_schedule = {'unit_id': unit_id, 'steps': {}}
        for step in steps:
            start = solver.Value(unit_step_intervals[(unit_id, step)].StartExpr())
            end = solver.Value(unit_step_intervals[(unit_id, step)].EndExpr())
            unit_schedule['steps'][step] = {'start': start, 'end': end}
        schedule.append(unit_schedule)
    schedule.sort(key=lambda x: x['steps']['step1']['start'])
    for unit_schedule in schedule:
        unit_id = unit_schedule['unit_id']
        print(f"제품 그룹: {unit_id}")
        for step in steps:
            start = unit_schedule['steps'][step]['start']
            end = unit_schedule['steps'][step]['end']
            print(f"  {step}: {start} 분에 시작, {end} 분에 종료")
else:
    print("해결 가능한 솔루션을 찾지 못했습니다.")
# Out:
# 총 작업 시간: 1932700.0 분
# 제품 그룹: 23D016-05
#   step1: 0 분에 시작, 8100 분에 종료
#   step2: 8100 분에 시작, 17800 분에 종료
#   step3: 17800 분에 시작, 31200 분에 종료
#   step4: 31200 분에 시작, 40300 분에 종료
#   step5: 41800 분에 시작, 50400 분에 종료
#   step6: 55200 분에 시작, 68100 분에 종료
# 제품 그룹: 23D017-32
#   step1: 8100 분에 시작, 19200 분에 종료
#   step2: 19200 분에 시작, 25200 분에 종료
#   step3: 25200 분에 시작, 28600 분에 종료
#   step4: 28600 분에 시작, 29600 분에 종료
#   step5: 29600 분에 시작, 41800 분에 종료
#   step6: 41800 분에 시작, 55200 분에 종료
# 제품 그룹: 23E004-02
#   step1: 19200 분에 시작, 27100 분에 종료
#   step2: 27100 분에 시작, 40400 분에 종료
#   step3: 40400 분에 시작, 51700 분에 종료
#   step4: 51700 분에 시작, 58200 분에 종료
#   step5: 58200 분에 시작, 64500 분에 종료
#   step6: 68100 분에 시작, 82400 분에 종료
# 제품 그룹: 23E009-03
#   step1: 27100 분에 시작, 37200 분에 종료
#   step2: 40400 분에 시작, 50400 분에 종료
#   step3: 50400 분에 시작, 58900 분에 종료
#   step4: 58900 분에 시작, 71200 분에 종료
#   step5: 71200 분에 시작, 80100 분에 종료
#   step6: 82400 분에 시작, 94000 분에 종료
# 제품 그룹: 23D017-29
#   step1: 37200 분에 시작, 48300 분에 종료
#   step2: 50400 분에 시작, 61500 분에 종료
#   step3: 61500 분에 시작, 73300 분에 종료
#   step4: 73300 분에 시작, 85400 분에 종료
#   step5: 85400 분에 시작, 85600 분에 종료
#   step6: 94000 분에 시작, 106300 분에 종료
# 제품 그룹: 23E008-02
#   step1: 48300 분에 시작, 56300 분에 종료
#   step2: 61500 분에 시작, 70900 분에 종료
#   step3: 70900 분에 시작, 80000 분에 종료
#   step4: 80000 분에 시작, 88700 분에 종료
#   step5: 88700 분에 시작, 96700 분에 종료
#   step6: 106300 분에 시작, 117500 분에 종료
# 제품 그룹: 23E009-02
#   step1: 56300 분에 시작, 65200 분에 종료
#   step2: 70900 분에 시작, 80600 분에 종료
#   step3: 80600 분에 시작, 89800 분에 종료
#   step4: 89800 분에 시작, 98100 분에 종료
#   step5: 98100 분에 시작, 111400 분에 종료
#   step6: 117500 분에 시작, 130400 분에 종료
# 제품 그룹: 23Y016-08
#   step1: 65200 분에 시작, 80400 분에 종료
#   step2: 80600 분에 시작, 92200 분에 종료
#   step3: 92200 분에 시작, 100000 분에 종료
#   step4: 100000 분에 시작, 111200 분에 종료
#   step5: 111400 분에 시작, 119700 분에 종료
#   step6: 130400 분에 시작, 143500 분에 종료
# 제품 그룹: 23Y018-01
#   step1: 80400 분에 시작, 88600 분에 종료
#   step2: 92200 분에 시작, 102300 분에 종료
#   step3: 102300 분에 시작, 110600 분에 종료
#   step4: 110600 분에 시작, 120400 분에 종료
#   step5: 120400 분에 시작, 141900 분에 종료
#   step6: 143500 분에 시작, 159700 분에 종료
# 제품 그룹: 23A012-03
#   step1: 88600 분에 시작, 97100 분에 종료
#   step2: 102300 분에 시작, 111800 분에 종료
#   step3: 111800 분에 시작, 119500 분에 종료
#   step4: 119500 분에 시작, 126700 분에 종료
#   step5: 141900 분에 시작, 145400 분에 종료
#   step6: 1822500 분에 시작, 1835000 분에 종료
# 제품 그룹: 23D023-04
#   step1: 97100 분에 시작, 109400 분에 종료
#   step2: 111800 분에 시작, 124000 분에 종료
#   step3: 124000 분에 시작, 134800 분에 종료
#   step4: 134800 분에 시작, 142700 분에 종료
#   step5: 145400 분에 시작, 155100 분에 종료
#   step6: 159700 분에 시작, 172600 분에 종료
# 제품 그룹: 23E018-08
#   step1: 109400 분에 시작, 119700 분에 종료
#   step2: 124000 분에 시작, 134800 분에 종료
#   step3: 134800 분에 시작, 147100 분에 종료
#   step4: 147100 분에 시작, 154600 분에 종료
#   step5: 155100 분에 시작, 164100 분에 종료
#   step6: 172600 분에 시작, 190900 분에 종료
# 제품 그룹: 23D022-01
#   step1: 119700 분에 시작, 128200 분에 종료
#   step2: 134800 분에 시작, 143800 분에 종료
#   step3: 143800 분에 시작, 154000 분에 종료
#   step4: 154000 분에 시작, 162500 분에 종료
#   step5: 164100 분에 시작, 174900 분에 종료
#   step6: 190900 분에 시작, 204000 분에 종료
# 제품 그룹: 23E004-01
#   step1: 128200 분에 시작, 137100 분에 종료
#   step2: 143800 분에 시작, 153900 분에 종료
#   step3: 153900 분에 시작, 161700 분에 종료
#   step4: 161700 분에 시작, 167200 분에 종료
#   step5: 174900 분에 시작, 184700 분에 종료
#   step6: 204000 분에 시작, 217300 분에 종료
# 제품 그룹: 23D021-01
#   step1: 137100 분에 시작, 149900 분에 종료
#   step2: 153900 분에 시작, 165400 분에 종료
#   step3: 165400 분에 시작, 171900 분에 종료
#   step4: 171900 분에 시작, 179000 분에 종료
#   step5: 184700 분에 시작, 197100 분에 종료
#   step6: 217300 분에 시작, 230700 분에 종료
# 제품 그룹: 23D021-20
#   step1: 149900 분에 시작, 159700 분에 종료
#   step2: 165400 분에 시작, 178500 분에 종료
#   step3: 178500 분에 시작, 185500 분에 종료
#   step4: 185500 분에 시작, 192300 분에 종료
#   step5: 197100 분에 시작, 210400 분에 종료
#   step6: 230700 분에 시작, 244100 분에 종료
# 제품 그룹: 23Y023-02
#   step1: 159700 분에 시작, 172900 분에 종료
#   step2: 178500 분에 시작, 191300 분에 종료
#   step3: 191300 분에 시작, 199700 분에 종료
#   step4: 199700 분에 시작, 207800 분에 종료
#   step5: 210400 분에 시작, 218400 분에 종료
#   step6: 724900 분에 시작, 742900 분에 종료
# 제품 그룹: 23D018-06
#   step1: 172900 분에 시작, 182200 분에 종료
#   step2: 191300 분에 시작, 201300 분에 종료
#   step3: 201300 분에 시작, 212200 분에 종료
#   step4: 212200 분에 시작, 220500 분에 종료
#   step5: 220500 분에 시작, 232200 분에 종료
#   step6: 244100 분에 시작, 257700 분에 종료
# 제품 그룹: 23D017-28
#   step1: 182200 분에 시작, 193300 분에 종료
#   step2: 201300 분에 시작, 213200 분에 종료
#   step3: 213200 분에 시작, 219300 분에 종료
#   step4: 219300 분에 시작, 230800 분에 종료
#   step5: 232200 분에 시작, 236700 분에 종료
#   step6: 970700 분에 시작, 981700 분에 종료
# 제품 그룹: 23E018-11
#   step1: 193300 분에 시작, 203900 분에 종료
#   step2: 213200 분에 시작, 226400 분에 종료
#   step3: 226400 분에 시작, 234300 분에 종료
#   step4: 234300 분에 시작, 239600 분에 종료
#   step5: 239600 분에 시작, 249400 분에 종료
#   step6: 257700 분에 시작, 271400 분에 종료
# 제품 그룹: 23D018-02
#   step1: 203900 분에 시작, 214200 분에 종료
#   step2: 226400 분에 시작, 235400 분에 종료
#   step3: 235400 분에 시작, 242700 분에 종료
#   step4: 242700 분에 시작, 251200 분에 종료
#   step5: 251200 분에 시작, 260100 분에 종료
#   step6: 271400 분에 시작, 285200 분에 종료
# 제품 그룹: 23A012-02
#   step1: 214200 분에 시작, 223100 분에 종료
#   step2: 235400 분에 시작, 245000 분에 종료
#   step3: 245000 분에 시작, 253900 분에 종료
#   step4: 253900 분에 시작, 262800 분에 종료
#   step5: 262800 분에 시작, 273800 분에 종료
#   step6: 285200 분에 시작, 299100 분에 종료
# 제품 그룹: 23E006-02
#   step1: 223100 분에 시작, 231500 분에 종료
#   step2: 245000 분에 시작, 254000 분에 종료
#   step3: 254000 분에 시작, 263200 분에 종료
#   step4: 263200 분에 시작, 274600 분에 종료
#   step5: 274600 분에 시작, 285000 분에 종료
#   step6: 1926600 분에 시작, 1932700 분에 종료
# 제품 그룹: 23Y016-05
#   step1: 231500 분에 시작, 241000 분에 종료
#   step2: 596300 분에 시작, 614300 분에 종료
#   step3: 614300 분에 시작, 621600 분에 종료
#   step4: 621600 분에 시작, 629400 분에 종료
#   step5: 636900 분에 시작, 645200 분에 종료
#   step6: 689400 분에 시작, 707000 분에 종료
# 제품 그룹: 23D007-02
#   step1: 241000 분에 시작, 251100 분에 종료
#   step2: 254000 분에 시작, 266600 분에 종료
#   step3: 266600 분에 시작, 276900 분에 종료
#   step4: 276900 분에 시작, 285700 분에 종료
#   step5: 285700 분에 시작, 295400 분에 종료
#   step6: 299100 분에 시작, 313600 분에 종료
# 제품 그룹: 23D017-08
#   step1: 251100 분에 시작, 260500 분에 종료
#   step2: 266600 분에 시작, 277600 분에 종료
#   step3: 277600 분에 시작, 284700 분에 종료
#   step4: 284700 분에 시작, 296300 분에 종료
#   step5: 296300 분에 시작, 300600 분에 종료
#   step6: 313600 분에 시작, 328100 분에 종료
# 제품 그룹: 23E020-01
#   step1: 260500 분에 시작, 269300 분에 종료
#   step2: 277600 분에 시작, 290200 분에 종료
#   step3: 290200 분에 시작, 298500 분에 종료
#   step4: 298500 분에 시작, 309500 분에 종료
#   step5: 309500 분에 시작, 318500 분에 종료
#   step6: 328100 분에 시작, 343000 분에 종료
# 제품 그룹: 23C009-06
#   step1: 269300 분에 시작, 279100 분에 종료
#   step2: 290200 분에 시작, 300900 분에 종료
#   step3: 300900 분에 시작, 309700 분에 종료
#   step4: 309700 분에 시작, 321000 분에 종료
#   step5: 321000 분에 시작, 329200 분에 종료
#   step6: 1780700 분에 시작, 1801600 분에 종료
# 제품 그룹: 23Y016-02
#   step1: 279100 분에 시작, 287000 분에 종료
#   step2: 300900 분에 시작, 311300 분에 종료
#   step3: 311300 분에 시작, 322700 분에 종료
#   step4: 322700 분에 시작, 333000 분에 종료
#   step5: 333000 분에 시작, 342700 분에 종료
#   step6: 343000 분에 시작, 365200 분에 종료
# 제품 그룹: 23D018-01
#   step1: 287000 분에 시작, 296500 분에 종료
#   step2: 326100 분에 시작, 335800 분에 종료
#   step3: 335800 분에 시작, 344300 분에 종료
#   step4: 344300 분에 시작, 352200 분에 종료
#   step5: 353300 분에 시작, 364000 분에 종료
#   step6: 365200 분에 시작, 380200 분에 종료
# 제품 그룹: 23D024-04
#   step1: 296500 분에 시작, 309300 분에 종료
#   step2: 311300 분에 시작, 326100 분에 종료
#   step3: 326100 분에 시작, 335100 분에 종료
#   step4: 335100 분에 시작, 345300 분에 종료
#   step5: 345300 분에 시작, 353300 분에 종료
#   step6: 637700 분에 시작, 654800 분에 종료
# 제품 그룹: 23E012-03
#   step1: 309300 분에 시작, 320500 분에 종료
#   step2: 335800 분에 시작, 346500 분에 종료
#   step3: 346500 분에 시작, 356400 분에 종료
#   step4: 356400 분에 시작, 364500 분에 종료
#   step5: 364500 분에 시작, 370400 분에 종료
#   step6: 380200 분에 시작, 395500 분에 종료
# 제품 그룹: 23E017-08
#   step1: 320500 분에 시작, 332200 분에 종료
#   step2: 346500 분에 시작, 358800 분에 종료
#   step3: 358800 분에 시작, 367000 분에 종료
#   step4: 367000 분에 시작, 374800 분에 종료
#   step5: 374800 분에 시작, 393100 분에 종료
#   step6: 395500 분에 시작, 410900 분에 종료
# 제품 그룹: 23E008-01
#   step1: 332200 분에 시작, 339700 분에 종료
#   step2: 358800 분에 시작, 369100 분에 종료
#   step3: 369100 분에 시작, 379600 분에 종료
#   step4: 379600 분에 시작, 389900 분에 종료
#   step5: 402700 분에 시작, 412700 분에 종료
#   step6: 947900 분에 시작, 958900 분에 종료
# 제품 그룹: 23D023-03
#   step1: 339700 분에 시작, 354300 분에 종료
#   step2: 378200 분에 시작, 391400 분에 종료
#   step3: 391400 분에 시작, 400600 분에 종료
#   step4: 400600 분에 시작, 408300 분에 종료
#   step5: 412700 분에 시작, 421800 분에 종료
#   step6: 426400 분에 시작, 441900 분에 종료
# 제품 그룹: 23D023-01
#   step1: 354300 분에 시작, 362300 분에 종료
#   step2: 369100 분에 시작, 378200 분에 종료
#   step3: 378200 분에 시작, 387600 분에 종료
#   step4: 387600 분에 시작, 389400 분에 종료
#   step5: 393100 분에 시작, 402700 분에 종료
#   step6: 410900 분에 시작, 426400 분에 종료
# 제품 그룹: 23E029-03
#   step1: 362300 분에 시작, 376900 분에 종료
#   step2: 391400 분에 시작, 404600 분에 종료
#   step3: 404600 분에 시작, 411900 분에 종료
#   step4: 411900 분에 시작, 422100 분에 종료
#   step5: 422100 분에 시작, 430400 분에 종료
#   step6: 441900 분에 시작, 457500 분에 종료
# 제품 그룹: 23D024-05
#   step1: 376900 분에 시작, 398000 분에 종료
#   step2: 404600 분에 시작, 418900 분에 종료
#   step3: 418900 분에 시작, 429400 분에 종료
#   step4: 429400 분에 시작, 440100 분에 종료
#   step5: 440100 분에 시작, 450100 분에 종료
#   step6: 958900 분에 시작, 970700 분에 종료
# 제품 그룹: 23D017-24
#   step1: 398000 분에 시작, 408900 분에 종료
#   step2: 418900 분에 시작, 429900 분에 종료
#   step3: 429900 분에 시작, 441800 분에 종료
#   step4: 441800 분에 시작, 453400 분에 종료
#   step5: 453400 분에 시작, 453500 분에 종료
#   step6: 457500 분에 시작, 473100 분에 종료
# 제품 그룹: 23D018-03
#   step1: 408900 분에 시작, 417100 분에 종료
#   step2: 429900 분에 시작, 439300 분에 종료
#   step3: 439300 분에 시작, 449400 분에 종료
#   step4: 449400 분에 시작, 456000 분에 종료
#   step5: 456000 분에 시작, 465200 분에 종료
#   step6: 473100 분에 시작, 488800 분에 종료
# 제품 그룹: 23E007-01
#   step1: 417100 분에 시작, 425400 분에 종료
#   step2: 439300 분에 시작, 448600 분에 종료
#   step3: 448600 분에 시작, 457500 분에 종료
#   step4: 457500 분에 시작, 467900 분에 종료
#   step5: 467900 분에 시작, 478000 분에 종료
#   step6: 671900 분에 시작, 689400 분에 종료
# 제품 그룹: 23Y023-01
#   step1: 425400 분에 시작, 437000 분에 종료
#   step2: 733200 분에 시작, 744900 분에 종료
#   step3: 744900 분에 시작, 752200 분에 종료
#   step4: 752200 분에 시작, 761600 분에 종료
#   step5: 782500 분에 시작, 801000 분에 종료
#   step6: 937500 분에 시작, 947900 분에 종료
# 제품 그룹: 23Y023-03
#   step1: 437000 분에 시작, 444300 분에 종료
#   step2: 448600 분에 시작, 461000 분에 종료
#   step3: 461000 분에 시작, 471700 분에 종료
#   step4: 471700 분에 시작, 478300 분에 종료
#   step5: 478300 분에 시작, 485100 분에 종료
#   step6: 488800 분에 시작, 504900 분에 종료
# 제품 그룹: 23D013-01
#   step1: 444300 분에 시작, 453600 분에 종료
#   step2: 461000 분에 시작, 470400 분에 종료
#   step3: 470400 분에 시작, 478900 분에 종료
#   step4: 478900 분에 시작, 487500 분에 종료
#   step5: 487500 분에 시작, 497900 분에 종료
#   step6: 504900 분에 시작, 521100 분에 종료
# 제품 그룹: 23E029-02
#   step1: 453600 분에 시작, 463100 분에 종료
#   step2: 470400 분에 시작, 482100 분에 종료
#   step3: 482100 분에 시작, 488900 분에 종료
#   step4: 488900 분에 시작, 499800 분에 종료
#   step5: 552700 분에 시작, 562500 분에 종료
#   step6: 897200 분에 시작, 917100 분에 종료
# 제품 그룹: 23E012-04
#   step1: 463100 분에 시작, 471500 분에 종료
#   step2: 482100 분에 시작, 492200 분에 종료
#   step3: 492200 분에 시작, 496600 분에 종료
#   step4: 496600 분에 시작, 503400 분에 종료
#   step5: 503400 분에 시작, 511500 분에 종료
#   step6: 521100 분에 시작, 537300 분에 종료
# 제품 그룹: 23D021-27
#   step1: 471500 분에 시작, 481600 분에 종료
#   step2: 492200 분에 시작, 505500 분에 종료
#   step3: 505500 분에 시작, 513000 분에 종료
#   step4: 513000 분에 시작, 513900 분에 종료
#   step5: 513900 분에 시작, 533500 분에 종료
#   step6: 537300 분에 시작, 553600 분에 종료
# 제품 그룹: 23D021-05
#   step1: 481600 분에 시작, 490600 분에 종료
#   step2: 505500 분에 시작, 515300 분에 종료
#   step3: 515300 분에 시작, 526400 분에 종료
#   step4: 526400 분에 시작, 537100 분에 종료
#   step5: 537100 분에 시작, 552700 분에 종료
#   step6: 553600 분에 시작, 570100 분에 종료
# 제품 그룹: 23D017-20
#   step1: 490600 분에 시작, 504500 분에 종료
#   step2: 515300 분에 시작, 530200 분에 종료
#   step3: 530200 분에 시작, 541900 분에 종료
#   step4: 541900 분에 시작, 553600 분에 종료
#   step5: 562500 분에 시작, 562600 분에 종료
#   step6: 570100 분에 시작, 586800 분에 종료
# 제품 그룹: 23D016-02
#   step1: 504500 분에 시작, 518300 분에 종료
#   step2: 530200 분에 시작, 542900 분에 종료
#   step3: 542900 분에 시작, 558600 분에 종료
#   step4: 558600 분에 시작, 567500 분에 종료
#   step5: 567500 분에 시작, 579700 분에 종료
#   step6: 586800 분에 시작, 603700 분에 종료
# 제품 그룹: 23D017-19
#   step1: 518300 분에 시작, 529200 분에 종료
#   step2: 542900 분에 시작, 554900 분에 종료
#   step3: 554900 분에 시작, 566600 분에 종료
#   step4: 566600 분에 시작, 578400 분에 종료
#   step5: 589800 분에 시작, 590100 분에 종료
#   step6: 1459500 분에 시작, 1482100 분에 종료
# 제품 그룹: 23D026-01
#   step1: 529200 분에 시작, 537900 분에 종료
#   step2: 554900 분에 시작, 563500 분에 종료
#   step3: 563500 분에 시작, 569200 분에 종료
#   step4: 569200 분에 시작, 577700 분에 종료
#   step5: 579700 분에 시작, 589800 분에 종료
#   step6: 603700 분에 시작, 620700 분에 종료
# 제품 그룹: 23E017-06
#   step1: 537900 분에 시작, 550400 분에 종료
#   step2: 563500 분에 시작, 576000 분에 종료
#   step3: 576000 분에 시작, 585800 분에 종료
#   step4: 585800 분에 시작, 595100 분에 종료
#   step5: 595100 분에 시작, 611200 분에 종료
#   step6: 620700 분에 시작, 637700 분에 종료
# 제품 그룹: 23D027-01
#   step1: 550400 분에 시작, 557300 분에 종료
#   step2: 586400 분에 시작, 596300 분에 종료
#   step3: 596300 분에 시작, 607300 분에 종료
#   step4: 607300 분에 시작, 609100 분에 종료
#   step5: 620400 분에 시작, 636900 분에 종료
#   step6: 654800 분에 시작, 671900 분에 종료
# 제품 그룹: 23Y022-01
#   step1: 557300 분에 시작, 563800 분에 종료
#   step2: 614300 분에 시작, 624500 분에 종료
#   step3: 624500 분에 시작, 632600 분에 종료
#   step4: 632600 분에 시작, 644000 분에 종료
#   step5: 645200 분에 시작, 665900 분에 종료
#   step6: 707000 분에 시작, 724900 분에 종료
# 제품 그룹: 23D021-04
#   step1: 563800 분에 시작, 572400 분에 종료
#   step2: 576000 분에 시작, 586400 분에 종료
#   step3: 586400 분에 시작, 597600 분에 종료
#   step4: 597600 분에 시작, 607500 분에 종료
#   step5: 611200 분에 시작, 620400 분에 종료
#   step6: 1482100 분에 시작, 1497700 분에 종료
# 제품 그룹: 23D025-05
#   step1: 572400 분에 시작, 584300 분에 종료
#   step2: 624500 분에 시작, 636500 분에 종료
#   step3: 636500 분에 시작, 645400 분에 종료
#   step4: 645400 분에 시작, 654100 분에 종료
#   step5: 665900 분에 시작, 677000 분에 종료
#   step6: 742900 분에 시작, 761700 분에 종료
# 제품 그룹: 23E019-01
#   step1: 584300 분에 시작, 596400 분에 종료
#   step2: 636500 분에 시작, 648900 분에 종료
#   step3: 648900 분에 시작, 660700 분에 종료
#   step4: 660700 분에 시작, 669400 분에 종료
#   step5: 677000 분에 시작, 684800 분에 종료
#   step6: 761700 분에 시작, 780600 분에 종료
# 제품 그룹: 23B004-15
#   step1: 596400 분에 시작, 606800 분에 종료
#   step2: 648900 분에 시작, 660200 분에 종료
#   step3: 660200 분에 시작, 672300 분에 종료
#   step4: 672300 분에 시작, 683400 분에 종료
#   step5: 684800 분에 시작, 698000 분에 종료
#   step6: 780600 분에 시작, 799700 분에 종료
# 제품 그룹: 23E020-02
#   step1: 606800 분에 시작, 616000 분에 종료
#   step2: 660200 분에 시작, 673300 분에 종료
#   step3: 673300 분에 시작, 680400 분에 종료
#   step4: 680400 분에 시작, 692900 분에 종료
#   step5: 698000 분에 시작, 710600 분에 종료
#   step6: 799700 분에 시작, 818900 분에 종료
# 제품 그룹: 23Y019-04
#   step1: 616000 분에 시작, 628100 분에 종료
#   step2: 673300 분에 시작, 685000 분에 종료
#   step3: 685000 분에 시작, 697500 분에 종료
#   step4: 697500 분에 시작, 707600 분에 종료
#   step5: 710600 분에 시작, 717900 분에 종료
#   step6: 818900 분에 시작, 838100 분에 종료
# 제품 그룹: 23D025-03
#   step1: 628100 분에 시작, 641700 분에 종료
#   step2: 685000 분에 시작, 697200 분에 종료
#   step3: 697200 분에 시작, 699000 분에 종료
#   step4: 699000 분에 시작, 706900 분에 종료
#   step5: 717900 분에 시작, 735500 분에 종료
#   step6: 838100 분에 시작, 857500 분에 종료
# 제품 그룹: 23D004-02
#   step1: 641700 분에 시작, 654300 분에 종료
#   step2: 697200 분에 시작, 709700 분에 종료
#   step3: 709700 분에 시작, 720700 분에 종료
#   step4: 720700 분에 시작, 727700 분에 종료
#   step5: 735500 분에 시작, 749000 분에 종료
#   step6: 857500 분에 시작, 877300 분에 종료
# 제품 그룹: 23D023-06
#   step1: 654300 분에 시작, 669400 분에 종료
#   step2: 709700 분에 시작, 723200 분에 종료
#   step3: 723200 분에 시작, 731900 분에 종료
#   step4: 731900 분에 시작, 740600 분에 종료
#   step5: 749000 분에 시작, 759700 분에 종료
#   step6: 877300 분에 시작, 897200 분에 종료
# 제품 그룹: 23D024-02
#   step1: 669400 분에 시작, 678200 분에 종료
#   step2: 723200 분에 시작, 733200 분에 종료
#   step3: 733200 분에 시작, 745600 분에 종료
#   step4: 745600 분에 시작, 754300 분에 종료
#   step5: 759700 분에 시작, 782500 분에 종료
#   step6: 917100 분에 시작, 937500 분에 종료
# 제품 그룹: 23Y019-03
#   step1: 678200 분에 시작, 686800 분에 종료
#   step2: 744900 분에 시작, 756700 분에 종료
#   step3: 756700 분에 시작, 764100 분에 종료
#   step4: 764100 분에 시작, 772400 분에 종료
#   step5: 801000 분에 시작, 807300 분에 종료
#   step6: 981700 분에 시작, 1436500 분에 종료
# 제품 그룹: 23D021-23
#   step1: 686800 분에 시작, 698800 분에 종료
#   step2: 756700 분에 시작, 768000 분에 종료
#   step3: 768000 분에 시작, 778400 분에 종료
#   step4: 778400 분에 시작, 788500 분에 종료
#   step5: 807300 분에 시작, 825600 분에 종료
#   step6: 1738600 분에 시작, 1759800 분에 종료
# 제품 그룹: 23A029-19
#   step1: 698800 분에 시작, 709500 분에 종료
#   step2: 768000 분에 시작, 779500 분에 종료
#   step3: 779500 분에 시작, 789900 분에 종료
#   step4: 789900 분에 시작, 800200 분에 종료
#   step5: 859200 분에 시작, 875700 분에 종료
#   step6: 1609100 분에 시작, 1630900 분에 종료
# 제품 그룹: 23D016-03
#   step1: 709500 분에 시작, 723900 분에 종료
#   step2: 811200 분에 시작, 823700 분에 종료
#   step3: 823700 분에 시작, 830400 분에 종료
#   step4: 830400 분에 시작, 842100 분에 종료
#   step5: 923500 분에 시작, 937400 분에 종료
#   step6: 1695900 분에 시작, 1717400 분에 종료
# 제품 그룹: 23D021-11
#   step1: 723900 분에 시작, 734800 분에 종료
#   step2: 779500 분에 시작, 791800 분에 종료
#   step3: 791800 분에 시작, 798400 분에 종료
#   step4: 798400 분에 시작, 810100 분에 종료
#   step5: 825600 분에 시작, 840900 분에 종료
#   step6: 1436500 분에 시작, 1459500 분에 종료
# 제품 그룹: 23D016-06
#   step1: 734800 분에 시작, 748400 분에 종료
#   step2: 844900 분에 시작, 857400 분에 종료
#   step3: 857400 분에 시작, 868300 분에 종료
#   step4: 868300 분에 시작, 876000 분에 종료
#   step5: 967400 분에 시작, 979500 분에 종료
#   step6: 1717400 분에 시작, 1738600 분에 종료
# 제품 그룹: 23D013-02
#   step1: 748400 분에 시작, 759500 분에 종료
#   step2: 823700 분에 시작, 834900 분에 종료
#   step3: 834900 분에 시작, 844400 분에 종료
#   step4: 844400 분에 시작, 853100 분에 종료
#   step5: 893200 분에 시작, 909500 분에 종료
#   step6: 1876500 분에 시작, 1897000 분에 종료
# 제품 그룹: 23E003-01
#   step1: 759500 분에 시작, 768200 분에 종료
#   step2: 791800 분에 시작, 801200 분에 종료
#   step3: 801200 분에 시작, 811700 분에 종료
#   step4: 811700 분에 시작, 821700 분에 종료
#   step5: 875700 분에 시작, 893200 분에 종료
#   step6: 1855800 분에 시작, 1876500 분에 종료
# 제품 그룹: 23D024-01
#   step1: 768200 분에 시작, 777200 분에 종료
#   step2: 801200 분에 시작, 811200 분에 종료
#   step3: 811200 분에 시작, 819300 분에 종료
#   step4: 819300 분에 시작, 829700 분에 종료
#   step5: 840900 분에 시작, 859200 분에 종료
#   step6: 1759800 분에 시작, 1780700 분에 종료
# 제품 그룹: 23D024-03
#   step1: 777200 분에 시작, 787600 분에 종료
#   step2: 887800 분에 시작, 899900 분에 종료
#   step3: 899900 분에 시작, 907200 분에 종료
#   step4: 907200 분에 시작, 918400 분에 종료
#   step5: 990900 분에 시작, 1001000 분에 종료
#   step6: 1520300 분에 시작, 1542800 분에 종료
# 제품 그룹: 23D020-03
#   step1: 787600 분에 시작, 797600 분에 종료
#   step2: 857400 분에 시작, 867400 분에 종료
#   step3: 867400 분에 시작, 876600 분에 종료
#   step4: 876600 분에 시작, 888000 분에 종료
#   step5: 979600 분에 시작, 990900 분에 종료
#   step6: 1674300 분에 시작, 1695900 분에 종료
# 제품 그룹: 23D021-25
#   step1: 797600 분에 시작, 805300 분에 종료
#   step2: 834900 분에 시작, 844900 분에 종료
#   step3: 844900 분에 시작, 858500 분에 종료
#   step4: 858500 분에 시작, 872100 분에 종료
#   step5: 1039000 분에 시작, 1044700 분에 종료
#   step6: 1565100 분에 시작, 1587300 분에 종료
# 제품 그룹: 23D017-06
#   step1: 805300 분에 시작, 816100 분에 종료
#   step2: 917000 분에 시작, 928000 분에 종료
#   step3: 928000 분에 시작, 941400 분에 종료
#   step4: 941400 분에 시작, 952100 분에 종료
#   step5: 1044700 분에 시작, 1048500 분에 종료
#   step6: 1497700 분에 시작, 1520300 분에 종료
# 제품 그룹: 23D020-04
#   step1: 816100 분에 시작, 824500 분에 종료
#   step2: 877300 분에 시작, 887800 분에 종료
#   step3: 887800 분에 시작, 899300 분에 종료
#   step4: 899300 분에 시작, 910700 분에 종료
#   step5: 1030800 분에 시작, 1039000 분에 종료
#   step6: 1630900 분에 시작, 1652700 분에 종료
# 제품 그룹: 23D025-01
#   step1: 824500 분에 시작, 834300 분에 종료
#   step2: 909100 분에 시작, 917000 분에 종료
#   step3: 917000 분에 시작, 923500 분에 종료
#   step4: 923500 분에 시작, 933700 분에 종료
#   step5: 937400 분에 시작, 953400 분에 종료
#   step6: 1801600 분에 시작, 1822500 분에 종료
# 제품 그룹: 23A012-04
#   step1: 834300 분에 시작, 843200 분에 종료
#   step2: 899900 분에 시작, 909100 분에 종료
#   step3: 909100 분에 시작, 919700 분에 종료
#   step4: 919700 분에 시작, 930200 분에 종료
#   step5: 1001000 분에 시작, 1012400 분에 종료
#   step6: 1897000 분에 시작, 1917500 분에 종료
# 제품 그룹: 23A012-01
#   step1: 843200 분에 시작, 852900 분에 종료
#   step2: 928000 분에 시작, 938200 분에 종료
#   step3: 938200 분에 시작, 948800 분에 종료
#   step4: 948800 분에 시작, 953000 분에 종료
#   step5: 953400 분에 시작, 967400 분에 종료
#   step6: 1542800 분에 시작, 1565100 분에 종료
# 제품 그룹: 23D017-31
#   step1: 852900 분에 시작, 861400 분에 종료
#   step2: 947600 분에 시작, 957500 분에 종료
#   step3: 957500 분에 시작, 963500 분에 종료
#   step4: 963500 분에 시작, 977300 분에 종료
#   step5: 979500 분에 시작, 979600 분에 종료
#   step6: 1917500 분에 시작, 1926600 분에 종료
# 제품 그룹: 23Y020-04
#   step1: 861400 분에 시작, 866800 분에 종료
#   step2: 867400 분에 시작, 877300 분에 종료
#   step3: 877300 분에 시작, 887800 분에 종료
#   step4: 887800 분에 시작, 897200 분에 종료
#   step5: 909500 분에 시작, 923500 분에 종료
#   step6: 1652700 분에 시작, 1674300 분에 종료
# 제품 그룹: 23D017-42
#   step1: 866800 분에 시작, 877000 분에 종료
#   step2: 938200 분에 시작, 947600 분에 종료
#   step3: 947600 분에 시작, 958100 분에 종료
#   step4: 958100 분에 시작, 968200 분에 종료
#   step5: 1022200 분에 시작, 1030800 분에 종료
#   step6: 1587300 분에 시작, 1609100 분에 종료
# 제품 그룹: 23D018-09
#   step1: 877000 분에 시작, 888000 분에 종료
#   step2: 957500 분에 시작, 965300 분에 종료
#   step3: 965300 분에 시작, 975400 분에 종료
#   step4: 975400 분에 시작, 985700 분에 종료
#   step5: 1012400 분에 시작, 1022200 분에 종료
#   step6: 1835000 분에 시작, 1855800 분에 종료

# %% [markdown]
# # 2번 경우를 고려한 최적화방법

# %%
import pandas as pd
from ortools.sat.python import cp_model

# 엑셀 데이터를 읽어옵니다.
df = pd.read_excel(file_path)

# NaN 값이 있는 행을 제거합니다.
df.dropna(inplace=True)

# 시간 단위를 정수로 변환하기 위한 스케일링 팩터를 정의합니다.
SCALE = 1000  # 소수점 이하 3자리까지 표현

# 제품 데이터를 단위 제품으로 만듭니다.
units = []

for idx, row in df.iterrows():
    processing_times = {
        'step1': int(round(row['step1 최종 작업 시간'] * SCALE)),
        'step2': int(round(row['step2 최종 작업 시간'] * SCALE)),
        'step3': int(round(row['step3 최종 작업 시간'] * SCALE)),
        'step4': int(round(row['step4 최종 작업 시간'] * SCALE)),
        'step5': int(round(row['step5 최종 작업 시간'] * SCALE)),
        'step6': int(round(row['step6 최종 작업 시간'] * SCALE)),
    }
    units.append({
        'unit_id': f"unit_{idx}",
        'processing_times': processing_times,
    })

# 스케줄링 문제를 정의합니다.
model = cp_model.CpModel()

steps = ['step1', 'step2', 'step3', 'step4', 'step5', 'step6']
machines_per_step = {
    'step1': 1,
    'step2': 1,
    'step3': 3,
    'step4': 4,
    'step5': 1,
    'step6': 1,
}

# 각 단위 제품과 단계에 대한 변수들을 정의합니다.
horizon = sum([u['processing_times'][s] for u in units for s in steps])
unit_step_intervals = {}

for unit in units:
    unit_id = unit['unit_id']
    processing_times = unit['processing_times']
    for step in steps:
        duration = processing_times[step]
        start_var = model.NewIntVar(0, horizon, f'start_{unit_id}_{step}')
        end_var = model.NewIntVar(0, horizon, f'end_{unit_id}_{step}')
        interval_var = model.NewIntervalVar(start_var, duration, end_var, f'interval_{unit_id}_{step}')
        unit_step_intervals[(unit_id, step)] = interval_var

# 단계별 선행 조건을 추가합니다.
for unit in units:
    unit_id = unit['unit_id']
    for s in range(len(steps) - 1):
        step_current = steps[s]
        step_next = steps[s + 1]
        end_current = unit_step_intervals[(unit_id, step_current)].EndExpr()
        start_next = unit_step_intervals[(unit_id, step_next)].StartExpr()
        model.Add(end_current <= start_next)

# 각 단계의 기계 용량 제약 조건을 추가합니다.
for step in steps:
    intervals = []
    for unit in units:
        unit_id = unit['unit_id']
        intervals.append(unit_step_intervals[(unit_id, step)])
    machine_capacity = machines_per_step[step]
    model.AddNoOverlap(intervals)

    if machine_capacity > 1:
        # 기계 용량이 1보다 큰 경우, Cumulative 제약 조건을 사용합니다.
        demands = [1] * len(intervals)
        model.AddCumulative(intervals, demands, machine_capacity)

# 총 작업 시간을 최소화하는 목표를 설정합니다.
makespan = model.NewIntVar(0, horizon, 'makespan')
end_times = [unit_step_intervals[(unit['unit_id'], 'step6')].EndExpr() for unit in units]
model.AddMaxEquality(makespan, end_times)
model.Minimize(makespan)

# 모델을 해결합니다.
solver = cp_model.CpSolver()
solver.parameters.max_time_in_seconds = 300.0
status = solver.Solve(model)

# 결과를 출력합니다.
if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
    total_time = solver.Value(makespan) / SCALE  # 원래 시간 단위로 환산
    print(f"총 작업 시간: {total_time} 분")
    schedule = []
    for unit in units:
        unit_id = unit['unit_id']
        unit_schedule = {'unit_id': unit_id, 'steps': {}}
        for step in steps:
            start = solver.Value(unit_step_intervals[(unit_id, step)].StartExpr()) / SCALE
            end = solver.Value(unit_step_intervals[(unit_id, step)].EndExpr()) / SCALE
            unit_schedule['steps'][step] = {'start': start, 'end': end}
        schedule.append(unit_schedule)
    schedule.sort(key=lambda x: x['steps']['step1']['start'])
    for unit_schedule in schedule:
        unit_id = unit_schedule['unit_id']
        print(f"제품: {unit_id}")
        for step in steps:
            start = unit_schedule['steps'][step]['start']
            end = unit_schedule['steps'][step]['end']
            print(f"  {step}: {start:.3f} 분에 시작, {end:.3f} 분에 종료")
else:
    print("해결 가능한 솔루션을 찾지 못했습니다.")
# Out:
# 총 작업 시간: 1928.9 분
# 제품: unit_85
#   step1: 0.000 분에 시작, 8.400 분에 종료
#   step2: 8.400 분에 시작, 18.500 분에 종료
#   step3: 18.500 분에 시작, 22.900 분에 종료
#   step4: 22.900 분에 시작, 29.700 분에 종료
#   step5: 29.700 분에 시작, 37.800 분에 종료
#   step6: 37.800 분에 시작, 54.000 분에 종료
# 제품: unit_117
#   step1: 8.400 분에 시작, 17.000 분에 종료
#   step2: 18.500 분에 시작, 30.300 분에 종료
#   step3: 30.300 분에 시작, 37.700 분에 종료
#   step4: 37.700 분에 시작, 46.000 분에 종료
#   step5: 46.000 분에 시작, 52.300 분에 종료
#   step6: 54.000 분에 시작, 508.800 분에 종료
# 제품: unit_59
#   step1: 20.600 분에 시작, 29.400 분에 종료
#   step2: 31.900 분에 시작, 41.900 분에 종료
#   step3: 42.300 분에 시작, 54.700 분에 종료
#   step4: 54.700 분에 시작, 63.400 분에 종료
#   step5: 70.700 분에 시작, 93.500 분에 종료
#   step6: 972.300 분에 시작, 992.700 분에 종료
# 제품: unit_4
#   step1: 29.400 분에 시작, 40.100 분에 종료
#   step2: 41.900 분에 시작, 53.400 분에 종료
#   step3: 54.700 분에 시작, 65.100 분에 종료
#   step4: 65.100 분에 시작, 75.400 분에 종료
#   step5: 93.500 분에 시작, 110.000 분에 종료
#   step6: 653.800 분에 시작, 675.600 분에 종료
# 제품: unit_15
#   step1: 40.100 분에 시작, 54.500 분에 종료
#   step2: 54.500 분에 시작, 67.000 분에 종료
#   step3: 67.000 분에 시작, 73.700 분에 종료
#   step4: 75.400 분에 시작, 87.100 분에 종료
#   step5: 110.000 분에 시작, 123.900 분에 종료
#   step6: 763.200 분에 시작, 784.700 분에 종료
# 제품: unit_14
#   step1: 54.500 분에 시작, 68.300 분에 종료
#   step2: 68.300 분에 시작, 81.000 분에 종료
#   step3: 81.000 분에 시작, 96.700 분에 종료
#   step4: 96.700 분에 시작, 105.600 분에 종료
#   step5: 139.200 분에 시작, 151.400 분에 종료
#   step6: 1324.400 분에 시작, 1341.300 분에 종료
# 제품: unit_45
#   step1: 68.300 분에 시작, 79.200 분에 종료
#   step2: 81.000 분에 시작, 93.300 분에 종료
#   step3: 96.700 분에 시작, 103.300 분에 종료
#   step4: 105.600 분에 시작, 117.300 분에 종료
#   step5: 123.900 분에 시작, 139.200 분에 종료
#   step6: 1423.200 분에 시작, 1446.200 분에 종료
# 제품: unit_62
#   step1: 79.200 분에 시작, 100.300 분에 종료
#   step2: 100.300 분에 시작, 114.600 분에 종료
#   step3: 114.600 분에 시작, 125.100 분에 종료
#   step4: 125.100 분에 시작, 135.800 분에 종료
#   step5: 755.200 분에 시작, 765.200 분에 종료
#   step6: 1850.900 분에 시작, 1862.700 분에 종료
# 제품: unit_18
#   step1: 100.300 분에 시작, 113.900 분에 종료
#   step2: 114.600 분에 시작, 127.100 분에 종료
#   step3: 127.100 분에 시작, 138.000 분에 종료
#   step4: 138.000 분에 시작, 145.700 분에 종료
#   step5: 151.400 분에 시작, 163.500 분에 종료
#   step6: 784.700 분에 시작, 805.900 분에 종료
# 제품: unit_12
#   step1: 113.900 분에 시작, 125.000 분에 종료
#   step2: 127.100 분에 시작, 138.300 분에 종료
#   step3: 138.300 분에 시작, 147.800 분에 종료
#   step4: 147.800 분에 시작, 156.500 분에 종료
#   step5: 163.500 분에 시작, 179.800 분에 종료
#   step6: 931.300 분에 시작, 951.800 분에 종료
# 제품: unit_6
#   step1: 125.000 분에 시작, 135.400 분에 종료
#   step2: 138.300 분에 시작, 149.600 분에 종료
#   step3: 149.600 분에 시작, 161.700 분에 종료
#   step4: 161.700 분에 시작, 172.800 분에 종료
#   step5: 179.800 분에 시작, 193.000 분에 종료
#   step6: 1110.100 분에 시작, 1129.200 분에 종료
# 제품: unit_90
#   step1: 135.400 분에 시작, 147.900 분에 종료
#   step2: 149.600 분에 시작, 162.100 분에 종료
#   step3: 162.100 분에 시작, 171.900 분에 종료
#   step4: 172.800 분에 시작, 182.100 분에 종료
#   step5: 284.500 분에 시작, 300.600 분에 종료
#   step6: 1290.400 분에 시작, 1307.400 분에 종료
# 제품: unit_70
#   step1: 147.900 분에 시작, 156.600 분에 종료
#   step2: 162.100 분에 시작, 171.500 분에 종료
#   step3: 171.900 분에 시작, 182.400 분에 종료
#   step4: 182.400 분에 시작, 192.400 분에 종료
#   step5: 193.000 분에 시작, 210.500 분에 종료
#   step6: 910.600 분에 시작, 931.300 분에 종료
# 제품: unit_58
#   step1: 156.600 분에 시작, 165.600 분에 종료
#   step2: 171.500 분에 시작, 181.500 분에 종료
#   step3: 182.400 분에 시작, 190.500 분에 종료
#   step4: 192.400 분에 시작, 202.800 분에 종료
#   step5: 210.500 분에 시작, 228.800 분에 종료
#   step6: 868.900 분에 시작, 889.800 분에 종료
# 제품: unit_56
#   step1: 165.600 분에 시작, 180.700 분에 종료
#   step2: 181.500 분에 시작, 195.000 분에 종료
#   step3: 195.000 분에 시작, 203.700 분에 종료
#   step4: 203.700 분에 시작, 212.400 분에 종료
#   step5: 378.200 분에 시작, 388.900 분에 종료
#   step6: 1012.600 분에 시작, 1032.500 분에 종료
# 제품: unit_9
#   step1: 180.700 분에 시작, 193.300 분에 종료
#   step2: 195.000 분에 시작, 207.500 분에 종료
#   step3: 207.500 분에 시작, 218.500 분에 종료
#   step4: 218.500 분에 시작, 225.500 분에 종료
#   step5: 228.800 분에 시작, 242.300 분에 종료
#   step6: 1032.500 분에 시작, 1052.300 분에 종료
# 제품: unit_122
#   step1: 193.300 분에 시작, 199.800 분에 종료
#   step2: 207.500 분에 시작, 217.700 분에 종료
#   step3: 218.500 분에 시작, 226.600 분에 종료
#   step4: 226.600 분에 시작, 238.000 분에 종료
#   step5: 242.300 분에 시작, 263.000 분에 종료
#   step6: 1203.200 분에 시작, 1221.100 분에 종료
# 제품: unit_116
#   step1: 199.800 분에 시작, 208.000 분에 종료
#   step2: 217.700 분에 시작, 227.800 분에 종료
#   step3: 227.800 분에 시작, 236.100 분에 종료
#   step4: 238.000 분에 시작, 247.800 분에 종료
#   step5: 263.000 분에 시작, 284.500 분에 종료
#   step6: 1390.800 분에 시작, 1407.000 분에 종료
# 제품: unit_106
#   step1: 208.000 분에 시작, 217.200 분에 종료
#   step2: 227.800 분에 시작, 240.900 분에 종료
#   step3: 240.900 분에 시작, 248.000 분에 종료
#   step4: 248.000 분에 시작, 260.500 분에 종료
#   step5: 355.900 분에 시작, 368.500 분에 종료
#   step6: 1090.900 분에 시작, 1110.100 분에 종료
# 제품: unit_92
#   step1: 217.200 분에 시작, 228.900 분에 종료
#   step2: 263.000 분에 시작, 275.300 분에 종료
#   step3: 275.300 분에 시작, 283.500 분에 종료
#   step4: 283.600 분에 시작, 291.400 분에 종료
#   step5: 300.600 분에 시작, 318.900 분에 종료
#   step6: 1548.800 분에 시작, 1564.200 분에 종료
# 제품: unit_60
#   step1: 228.900 분에 시작, 239.300 분에 종료
#   step2: 240.900 분에 시작, 253.000 분에 종료
#   step3: 253.000 분에 시작, 260.300 분에 종료
#   step4: 260.500 분에 시작, 271.700 분에 종료
#   step5: 330.200 분에 시작, 340.300 분에 종료
#   step6: 520.200 분에 시작, 542.700 분에 종료
# 제품: unit_40
#   step1: 239.300 분에 시작, 249.300 분에 종료
#   step2: 253.000 분에 시작, 263.000 분에 종료
#   step3: 263.000 분에 시작, 272.200 분에 종료
#   step4: 272.200 분에 시작, 283.600 분에 종료
#   step5: 318.900 분에 시작, 330.200 분에 종료
#   step6: 697.400 분에 시작, 719.000 분에 종료
# 제품: unit_47
#   step1: 249.300 분에 시작, 261.300 분에 종료
#   step2: 295.100 분에 시작, 306.400 분에 종료
#   step3: 310.000 분에 시작, 320.400 분에 종료
#   step4: 323.200 분에 시작, 333.300 분에 종료
#   step5: 484.400 분에 시작, 502.700 분에 종료
#   step6: 805.900 분에 시작, 827.100 분에 종료
# 제품: unit_48
#   step1: 261.400 분에 시작, 269.100 분에 종료
#   step2: 275.300 분에 시작, 285.300 분에 종료
#   step3: 285.300 분에 시작, 298.900 분에 종료
#   step4: 298.900 분에 시작, 312.500 분에 종료
#   step5: 397.100 분에 시작, 402.800 분에 종료
#   step6: 587.600 분에 시작, 609.800 분에 종료
# 제품: unit_44
#   step1: 269.100 분에 시작, 278.100 분에 종료
#   step2: 285.300 분에 시작, 295.100 분에 종료
#   step3: 298.900 분에 시작, 310.000 분에 종료
#   step4: 312.500 분에 시작, 323.200 분에 종료
#   step5: 340.300 분에 시작, 355.900 분에 종료
#   step6: 1358.000 분에 시작, 1374.500 분에 종료
# 제품: unit_65
#   step1: 278.100 분에 시작, 291.700 분에 종료
#   step2: 435.200 분에 시작, 447.400 분에 종료
#   step3: 447.400 분에 시작, 449.200 분에 종료
#   step4: 458.600 분에 시작, 466.500 분에 종료
#   step5: 466.800 분에 시작, 484.400 분에 종료
#   step6: 1052.300 분에 시작, 1071.700 분에 종료
# 제품: unit_19
#   step1: 291.700 분에 시작, 302.500 분에 종료
#   step2: 306.800 분에 시작, 317.800 분에 종료
#   step3: 322.500 분에 시작, 335.900 분에 종료
#   step4: 335.900 분에 시작, 346.600 분에 종료
#   step5: 556.900 분에 시작, 560.700 분에 종료
#   step6: 565.000 분에 시작, 587.600 분에 종료
# 제품: unit_113
#   step1: 302.500 분에 시작, 310.400 분에 종료
#   step2: 317.800 분에 시작, 328.200 분에 종료
#   step3: 335.900 분에 시작, 347.300 분에 종료
#   step4: 347.300 분에 시작, 357.600 분에 종료
#   step5: 368.500 분에 시작, 378.200 분에 종료
#   step6: 609.800 분에 시작, 632.000 분에 종료
# 제품: unit_61
#   step1: 310.400 분에 시작, 323.200 분에 종료
#   step2: 328.200 분에 시작, 343.000 분에 종료
#   step3: 347.300 분에 시작, 356.300 분에 종료
#   step4: 357.600 분에 시작, 367.800 분에 종료
#   step5: 605.600 분에 시작, 613.600 분에 종료
#   step6: 1256.200 분에 시작, 1273.300 분에 종료
# 제품: unit_41
#   step1: 323.200 분에 시작, 331.600 분에 종료
#   step2: 343.000 분에 시작, 353.500 분에 종료
#   step3: 356.300 분에 시작, 367.800 분에 종료
#   step4: 367.800 분에 시작, 379.200 분에 종료
#   step5: 537.300 분에 시작, 545.500 분에 종료
#   step6: 632.000 분에 시작, 653.800 분에 종료
# 제품: unit_78
#   step1: 331.600 분에 시작, 339.600 분에 종료
#   step2: 353.500 분에 시작, 362.900 분에 종료
#   step3: 367.800 분에 시작, 376.900 분에 종료
#   step4: 379.200 분에 시작, 387.900 분에 종료
#   step5: 388.900 분에 시작, 396.900 분에 종료
#   step6: 508.800 분에 시작, 520.000 분에 종료
# 제품: unit_67
#   step1: 343.700 분에 시작, 355.600 분에 종료
#   step2: 373.800 분에 시작, 385.800 분에 종료
#   step3: 386.100 분에 시작, 395.000 분에 종료
#   step4: 398.500 분에 시작, 407.200 분에 종료
#   step5: 430.200 분에 시작, 441.300 분에 종료
#   step6: 1148.100 분에 시작, 1166.900 분에 종료
# 제품: unit_63
#   step1: 355.600 분에 시작, 365.400 분에 종료
#   step2: 365.900 분에 시작, 373.800 분에 종료
#   step3: 379.600 분에 시작, 386.100 분에 종료
#   step4: 388.300 분에 시작, 398.500 분에 종료
#   step5: 402.800 분에 시작, 418.800 분에 종료
#   step6: 827.100 분에 시작, 848.000 분에 종료
# 제품: unit_3
#   step1: 365.400 분에 시작, 374.300 분에 종료
#   step2: 385.800 분에 시작, 395.000 분에 종료
#   step3: 395.000 분에 시작, 405.600 분에 종료
#   step4: 407.200 분에 시작, 417.700 분에 종료
#   step5: 418.800 분에 시작, 430.200 분에 종료
#   step6: 951.800 분에 시작, 972.300 분에 종료
# 제품: unit_0
#   step1: 374.300 분에 시작, 384.000 분에 종료
#   step2: 404.900 분에 시작, 415.100 분에 종료
#   step3: 416.100 분에 시작, 426.700 분에 종료
#   step4: 427.100 분에 시작, 431.300 분에 종료
#   step5: 444.200 분에 시작, 458.200 분에 종료
#   step6: 542.700 분에 시작, 565.000 분에 종료
# 제품: unit_121
#   step1: 384.000 분에 시작, 389.400 분에 종료
#   step2: 395.000 분에 시작, 404.900 분에 종료
#   step3: 405.600 분에 시작, 416.100 분에 종료
#   step4: 417.700 분에 시작, 427.100 분에 종료
#   step5: 513.500 분에 시작, 527.500 분에 종료
#   step6: 741.600 분에 시작, 763.200 분에 종료
# 제품: unit_30
#   step1: 389.400 분에 시작, 399.600 분에 종료
#   step2: 415.100 분에 시작, 424.500 분에 종료
#   step3: 426.700 분에 시작, 437.200 분에 종료
#   step4: 437.200 분에 시작, 447.300 분에 종료
#   step5: 458.200 분에 시작, 466.800 분에 종료
#   step6: 675.600 분에 시작, 697.400 분에 종료
# 제품: unit_39
#   step1: 399.600 분에 시작, 410.600 분에 종료
#   step2: 447.400 분에 시작, 455.200 분에 종료
#   step3: 455.200 분에 시작, 465.300 분에 종료
#   step4: 466.500 분에 시작, 476.800 분에 종료
#   step5: 527.500 분에 시작, 537.300 분에 종료
#   step6: 889.800 분에 시작, 910.600 분에 종료
# 제품: unit_7
#   step1: 410.600 분에 시작, 420.400 분에 종료
#   step2: 424.500 분에 시작, 435.200 분에 종료
#   step3: 437.200 분에 시작, 446.000 분에 종료
#   step4: 447.300 분에 시작, 458.600 분에 종료
#   step5: 505.300 분에 시작, 513.500 분에 종료
#   step6: 848.000 분에 시작, 868.900 분에 종료
# 제품: unit_22
#   step1: 420.400 분에 시작, 431.300 분에 종료
#   step2: 455.200 분에 시작, 467.200 분에 종료
#   step3: 467.200 분에 시작, 478.900 분에 종료
#   step4: 478.900 분에 시작, 490.700 분에 종료
#   step5: 710.500 분에 시작, 710.800 분에 종료
#   step6: 719.000 분에 시작, 741.600 분에 종료
# 제품: unit_53
#   step1: 431.300 분에 시작, 445.900 분에 종료
#   step2: 467.200 분에 시작, 480.400 분에 종료
#   step3: 480.400 분에 시작, 489.600 분에 종료
#   step4: 490.700 분에 시작, 498.400 분에 종료
#   step5: 613.600 분에 시작, 622.700 분에 종료
#   step6: 1533.300 분에 시작, 1548.800 분에 종료
# 제품: unit_110
#   step1: 445.900 분에 시작, 460.500 분에 종료
#   step2: 618.500 분에 시작, 631.700 분에 종료
#   step3: 631.700 분에 시작, 639.000 분에 종료
#   step4: 639.100 분에 시작, 649.300 분에 종료
#   step5: 651.700 분에 시작, 660.000 분에 종료
#   step6: 1471.000 분에 시작, 1486.600 분에 종료
# 제품: unit_23
#   step1: 460.500 분에 시작, 474.400 분에 종료
#   step2: 480.400 분에 시작, 495.300 분에 종료
#   step3: 495.300 분에 시작, 507.000 분에 종료
#   step4: 507.000 분에 시작, 518.700 분에 종료
#   step5: 883.000 분에 시작, 883.100 분에 종료
#   step6: 1341.300 분에 시작, 1358.000 분에 종료
# 제품: unit_123
#   step1: 474.400 분에 시작, 486.000 분에 종료
#   step2: 495.300 분에 시작, 507.000 분에 종료
#   step3: 507.000 분에 시작, 514.300 분에 종료
#   step4: 518.700 분에 시작, 528.100 분에 종료
#   step5: 999.100 분에 시작, 1017.600 분에 종료
#   step6: 1896.300 분에 시작, 1906.700 분에 종료
# 제품: unit_109
#   step1: 486.000 분에 시작, 495.500 분에 종료
#   step2: 507.000 분에 시작, 518.700 분에 종료
#   step3: 518.700 분에 시작, 525.500 분에 종료
#   step4: 528.100 분에 시작, 539.000 분에 종료
#   step5: 547.100 분에 시작, 556.900 분에 종료
#   step6: 992.700 분에 시작, 1012.600 분에 종료
# 제품: unit_114
#   step1: 495.500 분에 시작, 505.000 분에 종료
#   step2: 518.700 분에 시작, 536.700 분에 종료
#   step3: 536.700 분에 시작, 544.000 분에 종료
#   step4: 544.000 분에 시작, 551.800 분에 종료
#   step5: 560.700 분에 시작, 569.000 분에 종료
#   step6: 1221.100 분에 시작, 1238.700 분에 종료
# 제품: unit_124
#   step1: 505.000 분에 시작, 518.200 분에 종료
#   step2: 560.800 분에 시작, 573.600 분에 종료
#   step3: 573.600 분에 시작, 582.000 분에 종료
#   step4: 582.000 분에 시작, 590.100 분에 종료
#   step5: 597.600 분에 시작, 605.600 분에 종료
#   step6: 1185.200 분에 시작, 1203.200 분에 종료
# 제품: unit_99
#   step1: 518.200 분에 시작, 528.500 분에 종료
#   step2: 536.700 분에 시작, 547.500 분에 종료
#   step3: 547.500 분에 시작, 559.800 분에 종료
#   step4: 559.800 분에 시작, 567.300 분에 종료
#   step5: 569.000 분에 시작, 578.000 분에 종료
#   step6: 1166.900 분에 시작, 1185.200 분에 종료
# 제품: unit_49
#   step1: 528.500 분에 시작, 538.600 분에 종료
#   step2: 547.500 분에 시작, 560.800 분에 종료
#   step3: 560.800 분에 시작, 568.300 분에 종료
#   step4: 568.300 분에 시작, 569.200 분에 종료
#   step5: 578.000 분에 시작, 597.600 분에 종료
#   step6: 1374.500 분에 시작, 1390.800 분에 종료
# 제품: unit_115
#   step1: 538.600 분에 시작, 553.800 분에 종료
#   step2: 715.300 분에 시작, 726.900 분에 종료
#   step3: 727.700 분에 시작, 735.500 분에 종료
#   step4: 736.600 분에 시작, 747.800 분에 종료
#   step5: 791.300 분에 시작, 799.600 분에 종료
#   step6: 1761.200 분에 시작, 1774.300 분에 종료
# 제품: unit_10
#   step1: 553.800 분에 시작, 563.900 분에 종료
#   step2: 573.600 분에 시작, 586.200 분에 종료
#   step3: 586.200 분에 시작, 596.500 분에 종료
#   step4: 596.500 분에 시작, 605.300 분에 종료
#   step5: 631.900 분에 시작, 641.600 분에 종료
#   step6: 1609.400 분에 시작, 1623.900 분에 종료
# 제품: unit_54
#   step1: 563.900 분에 시작, 576.200 분에 종료
#   step2: 664.700 분에 시작, 676.900 분에 종료
#   step3: 676.900 분에 시작, 687.700 분에 종료
#   step4: 687.700 분에 시작, 695.600 분에 종료
#   step5: 710.800 분에 시작, 720.500 분에 종료
#   step6: 1787.400 분에 시작, 1800.300 분에 종료
# 제품: unit_43
#   step1: 576.200 분에 시작, 584.800 분에 종료
#   step2: 586.200 분에 시작, 596.600 분에 종료
#   step3: 596.600 분에 시작, 607.800 분에 종료
#   step4: 607.800 분에 시작, 617.700 분에 종료
#   step5: 622.700 분에 시작, 631.900 분에 종료
#   step6: 1502.200 분에 시작, 1517.800 분에 종료
# 제품: unit_105
#   step1: 584.800 분에 시작, 593.600 분에 종료
#   step2: 596.600 분에 시작, 609.200 분에 종료
#   step3: 609.200 분에 시작, 617.500 분에 종료
#   step4: 617.700 분에 시작, 628.700 분에 종료
#   step5: 660.000 분에 시작, 669.000 분에 종료
#   step6: 1594.500 분에 시작, 1609.400 분에 종료
# 제품: unit_76
#   step1: 593.600 분에 시작, 601.900 분에 종료
#   step2: 609.200 분에 시작, 618.500 분에 종료
#   step3: 618.500 분에 시작, 627.400 분에 종료
#   step4: 628.700 분에 시작, 639.100 분에 종료
#   step5: 641.600 분에 시작, 651.700 분에 종료
#   step6: 1238.700 분에 시작, 1256.200 분에 종료
# 제품: unit_38
#   step1: 601.900 분에 시작, 611.200 분에 종료
#   step2: 631.700 분에 시작, 641.700 분에 종료
#   step3: 641.700 분에 시작, 652.600 분에 종료
#   step4: 652.600 분에 시작, 660.900 분에 종료
#   step5: 698.800 분에 시작, 710.500 분에 종료
#   step6: 1694.100 분에 시작, 1707.700 분에 종료
# 제품: unit_42
#   step1: 611.200 분에 시작, 624.000 분에 종료
#   step2: 801.000 분에 시작, 812.500 분에 종료
#   step3: 814.200 분에 시작, 820.700 분에 종료
#   step4: 820.800 분에 시작, 827.900 분에 종료
#   step5: 835.900 분에 시작, 848.300 분에 종료
#   step6: 1734.500 분에 시작, 1747.900 분에 종료
# 제품: unit_46
#   step1: 624.000 분에 시작, 633.800 분에 종료
#   step2: 651.600 분에 시작, 664.700 분에 종료
#   step3: 664.700 분에 시작, 671.700 분에 종료
#   step4: 671.700 분에 시작, 678.500 분에 종료
#   step5: 685.500 분에 시작, 698.800 분에 종료
#   step6: 1707.700 분에 시작, 1721.100 분에 종료
# 제품: unit_69
#   step1: 633.800 분에 시작, 640.700 분에 종료
#   step2: 641.700 분에 시작, 651.600 분에 종료
#   step3: 652.600 분에 시작, 663.600 분에 종료
#   step4: 663.600 분에 시작, 665.400 분에 종료
#   step5: 669.000 분에 시작, 685.500 분에 종료
#   step6: 1273.300 분에 시작, 1290.400 분에 종료
# 제품: unit_11
#   step1: 640.700 분에 시작, 650.000 분에 종료
#   step2: 696.300 분에 시작, 705.700 분에 종료
#   step3: 710.300 분에 시작, 718.800 분에 종료
#   step4: 718.800 분에 시작, 727.400 분에 종료
#   step5: 733.800 분에 시작, 744.200 분에 종료
#   step6: 1407.000 분에 시작, 1423.200 분에 종료
# 제품: unit_80
#   step1: 650.000 분에 시작, 658.900 분에 종료
#   step2: 686.600 분에 시작, 696.300 분에 종료
#   step3: 701.100 분에 시작, 710.300 분에 종료
#   step4: 710.300 분에 시작, 718.600 분에 종료
#   step5: 720.500 분에 시작, 733.800 분에 종료
#   step6: 1800.300 분에 시작, 1813.200 분에 종료
# 제품: unit_17
#   step1: 658.900 분에 시작, 667.000 분에 종료
#   step2: 676.900 분에 시작, 686.600 분에 종료
#   step3: 687.700 분에 시작, 701.100 분에 종료
#   step4: 701.100 분에 시작, 710.200 분에 종료
#   step5: 775.900 분에 시작, 784.500 분에 종료
#   step6: 1813.200 분에 시작, 1826.100 분에 종료
# 제품: unit_81
#   step1: 667.000 분에 시작, 677.100 분에 종료
#   step2: 736.600 분에 시작, 746.600 분에 종료
#   step3: 746.600 분에 시작, 755.100 분에 종료
#   step4: 755.700 분에 시작, 768.000 분에 종료
#   step5: 848.300 분에 시작, 857.200 분에 종료
#   step6: 1873.700 분에 시작, 1885.300 분에 종료
# 제품: unit_35
#   step1: 677.100 분에 시작, 686.600 분에 종료
#   step2: 726.900 분에 시작, 736.600 분에 종료
#   step3: 736.600 분에 시작, 745.100 분에 종료
#   step4: 747.800 분에 시작, 755.700 분에 종료
#   step5: 765.200 분에 시작, 775.900 분에 종료
#   step6: 1579.500 분에 시작, 1594.500 분에 종료
# 제품: unit_1
#   step1: 686.600 분에 시작, 695.500 분에 종료
#   step2: 705.700 분에 시작, 715.300 분에 종료
#   step3: 718.800 분에 시작, 727.700 분에 종료
#   step4: 727.700 분에 시작, 736.600 분에 종료
#   step5: 744.200 분에 시작, 755.200 분에 종료
#   step6: 1652.700 분에 시작, 1666.600 분에 종료
# 제품: unit_24
#   step1: 695.500 분에 시작, 706.400 분에 종료
#   step2: 812.500 분에 시작, 823.500 분에 종료
#   step3: 823.500 분에 시작, 835.400 분에 종료
#   step4: 835.400 분에 시작, 847.000 분에 종료
#   step5: 883.100 분에 시작, 883.200 분에 종료
#   step6: 1486.600 분에 시작, 1502.200 분에 종료
# 제품: unit_84
#   step1: 706.400 분에 시작, 717.600 분에 종료
#   step2: 832.100 분에 시작, 842.800 분에 종료
#   step3: 842.800 분에 시작, 852.700 분에 종료
#   step4: 855.500 분에 시작, 863.600 분에 종료
#   step5: 867.300 분에 시작, 873.200 분에 종료
#   step6: 1564.200 분에 시작, 1579.500 분에 종료
# 제품: unit_102
#   step1: 717.600 분에 시작, 728.200 분에 종료
#   step2: 842.800 분에 시작, 856.000 분에 종료
#   step3: 856.000 분에 시작, 863.900 분에 종료
#   step4: 863.900 분에 시작, 869.200 분에 종료
#   step5: 873.200 분에 시작, 883.000 분에 종료
#   step6: 1680.400 분에 시작, 1694.100 분에 종료
# 제품: unit_50
#   step1: 728.200 분에 시작, 736.700 분에 종료
#   step2: 782.600 분에 시작, 791.600 분에 종료
#   step3: 793.900 분에 시작, 804.100 분에 종료
#   step4: 804.100 분에 시작, 812.600 분에 종료
#   step5: 815.900 분에 시작, 826.700 분에 종료
#   step6: 1774.300 분에 시작, 1787.400 분에 종료
# 제품: unit_125
#   step1: 736.700 분에 시작, 744.000 분에 종료
#   step2: 746.600 분에 시작, 759.000 분에 종료
#   step3: 759.000 분에 시작, 769.700 분에 종료
#   step4: 769.700 분에 시작, 776.300 분에 종료
#   step5: 784.500 분에 시작, 791.300 분에 종료
#   step6: 1906.700 분에 시작, 1922.800 분에 종료
# 제품: unit_77
#   step1: 744.000 분에 시작, 751.500 분에 종료
#   step2: 759.000 분에 시작, 769.300 분에 종료
#   step3: 769.700 분에 시작, 780.200 분에 종료
#   step4: 780.200 분에 시작, 790.500 분에 종료
#   step5: 799.600 분에 시작, 809.600 분에 종료
#   step6: 1862.700 분에 시작, 1873.700 분에 종료
# 제품: unit_73
#   step1: 751.500 분에 시작, 759.400 분에 종료
#   step2: 769.300 분에 시작, 782.600 분에 종료
#   step3: 782.600 분에 시작, 793.900 분에 종료
#   step4: 793.900 분에 시작, 800.400 분에 종료
#   step5: 809.600 분에 시작, 815.900 분에 종료
#   step6: 1638.400 분에 시작, 1652.700 분에 종료
# 제품: unit_37
#   step1: 759.400 분에 시작, 767.600 분에 종료
#   step2: 791.600 분에 시작, 801.000 분에 종료
#   step3: 804.100 분에 시작, 814.200 분에 종료
#   step4: 814.200 분에 시작, 820.800 분에 종료
#   step5: 826.700 분에 시작, 835.900 분에 종료
#   step6: 1455.300 분에 시작, 1471.000 분에 종료
# 제품: unit_68
#   step1: 767.600 분에 시작, 776.300 분에 종료
#   step2: 823.500 분에 시작, 832.100 분에 종료
#   step3: 835.400 분에 시작, 841.100 분에 종료
#   step4: 847.000 분에 시작, 855.500 분에 종료
#   step5: 857.200 분에 시작, 867.300 분에 종료
#   step6: 1307.400 분에 시작, 1324.400 분에 종료
# 제품: unit_26
#   step1: 776.300 분에 시작, 787.400 분에 종료
#   step2: 876.000 분에 시작, 887.100 분에 종료
#   step3: 887.100 분에 시작, 898.900 분에 종료
#   step4: 898.900 분에 시작, 911.000 분에 종료
#   step5: 911.000 분에 시작, 911.200 분에 종료
#   step6: 1838.600 분에 시작, 1850.900 분에 종료
# 제품: unit_20
#   step1: 787.400 분에 시작, 796.800 분에 종료
#   step2: 856.000 분에 시작, 867.000 분에 종료
#   step3: 867.000 분에 시작, 874.100 분에 종료
#   step4: 874.100 분에 시작, 885.700 분에 종료
#   step5: 885.700 분에 시작, 890.000 분에 종료
#   step6: 1623.900 분에 시작, 1638.400 분에 종료
# 제품: unit_36
#   step1: 796.800 분에 시작, 807.100 분에 종료
#   step2: 867.000 분에 시작, 876.000 분에 종료
#   step3: 876.000 분에 시작, 883.300 분에 종료
#   step4: 885.700 분에 시작, 894.200 분에 종료
#   step5: 894.200 분에 시작, 903.100 분에 종료
#   step6: 1666.600 분에 시작, 1680.400 분에 종료
# 제품: unit_25
#   step1: 807.100 분에 시작, 818.200 분에 종료
#   step2: 934.800 분에 시작, 946.700 분에 종료
#   step3: 946.700 분에 시작, 952.800 분에 종료
#   step4: 952.800 분에 시작, 964.300 분에 종료
#   step5: 964.700 분에 시작, 969.200 분에 종료
#   step6: 1885.300 분에 시작, 1896.300 분에 종료
# 제품: unit_72
#   step1: 818.200 분에 시작, 827.100 분에 종료
#   step2: 887.100 분에 시작, 897.200 분에 종료
#   step3: 898.900 분에 시작, 906.700 분에 종료
#   step4: 911.000 분에 시작, 916.500 분에 종료
#   step5: 916.500 분에 시작, 926.300 분에 종료
#   step6: 1747.900 분에 시작, 1761.200 분에 종료
# 제품: unit_75
#   step1: 827.100 분에 시작, 835.500 분에 종료
#   step2: 906.600 분에 시작, 915.600 분에 종료
#   step3: 915.800 분에 시작, 925.000 분에 종료
#   step4: 925.200 분에 시작, 936.600 분에 종료
#   step5: 936.600 분에 시작, 947.000 분에 종료
#   step6: 1922.800 분에 시작, 1928.900 분에 종료
# 제품: unit_118
#   step1: 835.500 분에 시작, 847.600 분에 종료
#   step2: 972.100 분에 시작, 983.800 분에 종료
#   step3: 983.800 분에 시작, 996.300 분에 종료
#   step4: 996.300 분에 시작, 1006.400 분에 종료
#   step5: 1017.600 분에 시작, 1024.900 분에 종료
#   step6: 1071.700 분에 시작, 1090.900 분에 종료
# 제품: unit_51
#   step1: 851.900 분에 시작, 859.900 분에 종료
#   step2: 925.700 분에 시작, 934.800 분에 종료
#   step3: 934.800 분에 시작, 944.200 분에 종료
#   step4: 944.200 분에 시작, 946.000 분에 종료
#   step5: 947.000 분에 시작, 956.600 분에 종료
#   step6: 1517.800 분에 시작, 1533.300 분에 종료
# 제품: unit_2
#   step1: 859.900 분에 시작, 868.400 분에 종료
#   step2: 946.700 분에 시작, 956.200 분에 종료
#   step3: 956.200 분에 시작, 963.900 분에 종료
#   step4: 964.300 분에 시작, 971.500 분에 종료
#   step5: 971.500 분에 시작, 975.000 분에 종료
#   step6: 1826.100 분에 시작, 1838.600 분에 종료
# 제품: unit_28
#   step1: 868.400 분에 시작, 876.900 분에 종료
#   step2: 956.200 분에 시작, 966.100 분에 종료
#   step3: 966.100 분에 시작, 972.100 분에 종료
#   step4: 972.100 분에 시작, 985.900 분에 종료
#   step5: 985.900 분에 시작, 986.000 분에 종료
#   step6: 1446.200 분에 시작, 1455.300 분에 종료
# 제품: unit_29
#   step1: 876.900 분에 시작, 888.000 분에 종료
#   step2: 966.100 분에 시작, 972.100 분에 종료
#   step3: 972.100 분에 시작, 975.500 분에 종료
#   step4: 985.900 분에 시작, 986.900 분에 종료
#   step5: 986.900 분에 시작, 999.100 분에 종료
#   step6: 1721.100 분에 시작, 1734.500 분에 종료
# 제품: unit_104
#   step1: 888.000 분에 시작, 900.100 분에 종료
#   step2: 983.800 분에 시작, 996.200 분에 종료
#   step3: 996.300 분에 시작, 1008.100 분에 종료
#   step4: 1008.100 분에 시작, 1016.800 분에 종료
#   step5: 1024.900 분에 시작, 1032.700 분에 종료
#   step6: 1129.200 분에 시작, 1148.100 분에 종료

# %% [markdown]
# #Pipe의 공정 순서 배열 엑셀 데이터를 바탕으로 공정 전체 소요시간을 계산하는 코드

# %%
import pandas as pd
from ortools.sat.python import cp_model

# 엑셀 데이터를 읽어옵니다.
df = pd.read_excel(file_path)

# NaN 값이 있는 행을 제거합니다.
df.dropna(inplace=True)

# 제품 데이터를 단위 제품으로 만듭니다.
units = []
# **시간 단위를 정수로 변환하기 위한 스케일링 팩터를 정의합니다.**
SCALE = 1000  # 소수점 이하 3자리까지 표현


for idx, row in df.iterrows():
    product_group = row['제품군']
    processing_times = {
        'step1': int(round(row['step1 최종 작업 시간'] * SCALE)),
        'step2': int(round(row['step2 최종 작업 시간'] * SCALE)),
        'step3': int(round(row['step3 최종 작업 시간'] * SCALE)),
        'step4': int(round(row['step4 최종 작업 시간'] * SCALE)),
        'step5': int(round(row['step5 최종 작업 시간'] * SCALE)),
        'step6': int(round(row['step6 최종 작업 시간'] * SCALE)),
    }
    units.append({
        'unit_id': f"{product_group}",
        'product_group': product_group,
        'processing_times': processing_times,
    })

# 스케줄링 문제를 정의합니다.
model = cp_model.CpModel()

steps = ['step1', 'step2', 'step3', 'step4', 'step5', 'step6']
machines_per_step = {
    'step1': 1,
    'step2': 1,
    'step3': 3,
    'step4': 4,
    'step5': 1,
    'step6': 1,
}

# 각 단위 제품과 단계에 대한 변수들을 정의합니다.
horizon = sum([u['processing_times'][s] for u in units for s in steps])
unit_step_intervals = {}

for unit in units:
    unit_id = unit['unit_id']
    processing_times = unit['processing_times']
    for step in steps:
        duration = int(processing_times[step])
        start_var = model.NewIntVar(0, horizon, f'start_{unit_id}_{step}')
        end_var = model.NewIntVar(0, horizon, f'end_{unit_id}_{step}')
        interval_var = model.NewIntervalVar(start_var, duration, end_var, f'interval_{unit_id}_{step}')
        unit_step_intervals[(unit_id, step)] = interval_var

# 단계별 선행 조건을 추가합니다.
for unit in units:
    unit_id = unit['unit_id']
    for s in range(len(steps) - 1):
        step_current = steps[s]
        step_next = steps[s + 1]
        end_current = unit_step_intervals[(unit_id, step_current)].EndExpr()
        start_next = unit_step_intervals[(unit_id, step_next)].StartExpr()
        model.Add(end_current <= start_next)

# 각 단계의 기계 용량 제약 조건을 추가합니다.
for step in steps:
    intervals = []
    demands = []
    for unit in units:
        unit_id = unit['unit_id']
        intervals.append(unit_step_intervals[(unit_id, step)])
        demands.append(1)
    machine_capacity = machines_per_step[step]
    model.AddCumulative(intervals, demands, machine_capacity)

# 총 작업 시간을 최소화하는 목표를 설정합니다.
makespan = model.NewIntVar(0, horizon, 'makespan')
end_times = []
for unit in units:
    unit_id = unit['unit_id']
    end_times.append(unit_step_intervals[(unit_id, 'step6')].EndExpr())
model.AddMaxEquality(makespan, end_times)
model.Minimize(makespan)

# 모델을 해결합니다.
solver = cp_model.CpSolver()
solver.parameters.max_time_in_seconds = 300.0
status = solver.Solve(model)

# 결과를 출력합니다.
if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
    print(f"총 작업 시간: {solver.ObjectiveValue()} 분")
    schedule = []
    for unit in units:
        unit_id = unit['unit_id']
        unit_schedule = {'unit_id': unit_id, 'steps': {}}
        for step in steps:
            start = solver.Value(unit_step_intervals[(unit_id, step)].StartExpr())
            end = solver.Value(unit_step_intervals[(unit_id, step)].EndExpr())
            unit_schedule['steps'][step] = {'start': start, 'end': end}
        schedule.append(unit_schedule)
    schedule.sort(key=lambda x: x['steps']['step1']['start'])
    for unit_schedule in schedule:
        unit_id = unit_schedule['unit_id']
        print(f"제품 그룹: {unit_id}")
        for step in steps:
            start = unit_schedule['steps'][step]['start']
            end = unit_schedule['steps'][step]['end']
            print(f"  {step}: {start} 분에 시작, {end} 분에 종료")
else:
    print("해결 가능한 솔루션을 찾지 못했습니다.")
# Out:
# 총 작업 시간: 1932700.0 분
# 제품 그룹: 23D016-05
#   step1: 0 분에 시작, 8100 분에 종료
#   step2: 8100 분에 시작, 17800 분에 종료
#   step3: 17800 분에 시작, 31200 분에 종료
#   step4: 31200 분에 시작, 40300 분에 종료
#   step5: 41800 분에 시작, 50400 분에 종료
#   step6: 55200 분에 시작, 68100 분에 종료
# 제품 그룹: 23D017-32
#   step1: 8100 분에 시작, 19200 분에 종료
#   step2: 19200 분에 시작, 25200 분에 종료
#   step3: 25200 분에 시작, 28600 분에 종료
#   step4: 28600 분에 시작, 29600 분에 종료
#   step5: 29600 분에 시작, 41800 분에 종료
#   step6: 41800 분에 시작, 55200 분에 종료
# 제품 그룹: 23E004-02
#   step1: 19200 분에 시작, 27100 분에 종료
#   step2: 27100 분에 시작, 40400 분에 종료
#   step3: 40400 분에 시작, 51700 분에 종료
#   step4: 51700 분에 시작, 58200 분에 종료
#   step5: 58200 분에 시작, 64500 분에 종료
#   step6: 68100 분에 시작, 82400 분에 종료
# 제품 그룹: 23E009-03
#   step1: 27100 분에 시작, 37200 분에 종료
#   step2: 40400 분에 시작, 50400 분에 종료
#   step3: 50400 분에 시작, 58900 분에 종료
#   step4: 58900 분에 시작, 71200 분에 종료
#   step5: 71200 분에 시작, 80100 분에 종료
#   step6: 82400 분에 시작, 94000 분에 종료
# 제품 그룹: 23D017-29
#   step1: 37200 분에 시작, 48300 분에 종료
#   step2: 50400 분에 시작, 61500 분에 종료
#   step3: 61500 분에 시작, 73300 분에 종료
#   step4: 73300 분에 시작, 85400 분에 종료
#   step5: 85400 분에 시작, 85600 분에 종료
#   step6: 94000 분에 시작, 106300 분에 종료
# 제품 그룹: 23E008-02
#   step1: 48300 분에 시작, 56300 분에 종료
#   step2: 61500 분에 시작, 70900 분에 종료
#   step3: 70900 분에 시작, 80000 분에 종료
#   step4: 80000 분에 시작, 88700 분에 종료
#   step5: 88700 분에 시작, 96700 분에 종료
#   step6: 106300 분에 시작, 117500 분에 종료
# 제품 그룹: 23E009-02
#   step1: 56300 분에 시작, 65200 분에 종료
#   step2: 70900 분에 시작, 80600 분에 종료
#   step3: 80600 분에 시작, 89800 분에 종료
#   step4: 89800 분에 시작, 98100 분에 종료
#   step5: 98100 분에 시작, 111400 분에 종료
#   step6: 117500 분에 시작, 130400 분에 종료
# 제품 그룹: 23Y016-08
#   step1: 65200 분에 시작, 80400 분에 종료
#   step2: 80600 분에 시작, 92200 분에 종료
#   step3: 92200 분에 시작, 100000 분에 종료
#   step4: 100000 분에 시작, 111200 분에 종료
#   step5: 111400 분에 시작, 119700 분에 종료
#   step6: 130400 분에 시작, 143500 분에 종료
# 제품 그룹: 23Y018-01
#   step1: 80400 분에 시작, 88600 분에 종료
#   step2: 92200 분에 시작, 102300 분에 종료
#   step3: 102300 분에 시작, 110600 분에 종료
#   step4: 110600 분에 시작, 120400 분에 종료
#   step5: 120400 분에 시작, 141900 분에 종료
#   step6: 143500 분에 시작, 159700 분에 종료
# 제품 그룹: 23A012-03
#   step1: 88600 분에 시작, 97100 분에 종료
#   step2: 102300 분에 시작, 111800 분에 종료
#   step3: 111800 분에 시작, 119500 분에 종료
#   step4: 119500 분에 시작, 126700 분에 종료
#   step5: 141900 분에 시작, 145400 분에 종료
#   step6: 1822500 분에 시작, 1835000 분에 종료
# 제품 그룹: 23D023-04
#   step1: 97100 분에 시작, 109400 분에 종료
#   step2: 111800 분에 시작, 124000 분에 종료
#   step3: 124000 분에 시작, 134800 분에 종료
#   step4: 134800 분에 시작, 142700 분에 종료
#   step5: 145400 분에 시작, 155100 분에 종료
#   step6: 159700 분에 시작, 172600 분에 종료
# 제품 그룹: 23E018-08
#   step1: 109400 분에 시작, 119700 분에 종료
#   step2: 124000 분에 시작, 134800 분에 종료
#   step3: 134800 분에 시작, 147100 분에 종료
#   step4: 147100 분에 시작, 154600 분에 종료
#   step5: 155100 분에 시작, 164100 분에 종료
#   step6: 172600 분에 시작, 190900 분에 종료
# 제품 그룹: 23D022-01
#   step1: 119700 분에 시작, 128200 분에 종료
#   step2: 134800 분에 시작, 143800 분에 종료
#   step3: 143800 분에 시작, 154000 분에 종료
#   step4: 154000 분에 시작, 162500 분에 종료
#   step5: 164100 분에 시작, 174900 분에 종료
#   step6: 190900 분에 시작, 204000 분에 종료
# 제품 그룹: 23E004-01
#   step1: 128200 분에 시작, 137100 분에 종료
#   step2: 143800 분에 시작, 153900 분에 종료
#   step3: 153900 분에 시작, 161700 분에 종료
#   step4: 161700 분에 시작, 167200 분에 종료
#   step5: 174900 분에 시작, 184700 분에 종료
#   step6: 204000 분에 시작, 217300 분에 종료
# 제품 그룹: 23D021-01
#   step1: 137100 분에 시작, 149900 분에 종료
#   step2: 153900 분에 시작, 165400 분에 종료
#   step3: 165400 분에 시작, 171900 분에 종료
#   step4: 171900 분에 시작, 179000 분에 종료
#   step5: 184700 분에 시작, 197100 분에 종료
#   step6: 217300 분에 시작, 230700 분에 종료
# 제품 그룹: 23D021-20
#   step1: 149900 분에 시작, 159700 분에 종료
#   step2: 165400 분에 시작, 178500 분에 종료
#   step3: 178500 분에 시작, 185500 분에 종료
#   step4: 185500 분에 시작, 192300 분에 종료
#   step5: 197100 분에 시작, 210400 분에 종료
#   step6: 230700 분에 시작, 244100 분에 종료
# 제품 그룹: 23Y023-02
#   step1: 159700 분에 시작, 172900 분에 종료
#   step2: 178500 분에 시작, 191300 분에 종료
#   step3: 191300 분에 시작, 199700 분에 종료
#   step4: 199700 분에 시작, 207800 분에 종료
#   step5: 210400 분에 시작, 218400 분에 종료
#   step6: 724900 분에 시작, 742900 분에 종료
# 제품 그룹: 23D018-06
#   step1: 172900 분에 시작, 182200 분에 종료
#   step2: 191300 분에 시작, 201300 분에 종료
#   step3: 201300 분에 시작, 212200 분에 종료
#   step4: 212200 분에 시작, 220500 분에 종료
#   step5: 220500 분에 시작, 232200 분에 종료
#   step6: 244100 분에 시작, 257700 분에 종료
# 제품 그룹: 23D017-28
#   step1: 182200 분에 시작, 193300 분에 종료
#   step2: 201300 분에 시작, 213200 분에 종료
#   step3: 213200 분에 시작, 219300 분에 종료
#   step4: 219300 분에 시작, 230800 분에 종료
#   step5: 232200 분에 시작, 236700 분에 종료
#   step6: 970700 분에 시작, 981700 분에 종료
# 제품 그룹: 23E018-11
#   step1: 193300 분에 시작, 203900 분에 종료
#   step2: 213200 분에 시작, 226400 분에 종료
#   step3: 226400 분에 시작, 234300 분에 종료
#   step4: 234300 분에 시작, 239600 분에 종료
#   step5: 239600 분에 시작, 249400 분에 종료
#   step6: 257700 분에 시작, 271400 분에 종료
# 제품 그룹: 23D018-02
#   step1: 203900 분에 시작, 214200 분에 종료
#   step2: 226400 분에 시작, 235400 분에 종료
#   step3: 235400 분에 시작, 242700 분에 종료
#   step4: 242700 분에 시작, 251200 분에 종료
#   step5: 251200 분에 시작, 260100 분에 종료
#   step6: 271400 분에 시작, 285200 분에 종료
# 제품 그룹: 23A012-02
#   step1: 214200 분에 시작, 223100 분에 종료
#   step2: 235400 분에 시작, 245000 분에 종료
#   step3: 245000 분에 시작, 253900 분에 종료
#   step4: 253900 분에 시작, 262800 분에 종료
#   step5: 262800 분에 시작, 273800 분에 종료
#   step6: 285200 분에 시작, 299100 분에 종료
# 제품 그룹: 23E006-02
#   step1: 223100 분에 시작, 231500 분에 종료
#   step2: 245000 분에 시작, 254000 분에 종료
#   step3: 254000 분에 시작, 263200 분에 종료
#   step4: 263200 분에 시작, 274600 분에 종료
#   step5: 274600 분에 시작, 285000 분에 종료
#   step6: 1926600 분에 시작, 1932700 분에 종료
# 제품 그룹: 23Y016-05
#   step1: 231500 분에 시작, 241000 분에 종료
#   step2: 596300 분에 시작, 614300 분에 종료
#   step3: 614300 분에 시작, 621600 분에 종료
#   step4: 621600 분에 시작, 629400 분에 종료
#   step5: 636900 분에 시작, 645200 분에 종료
#   step6: 689400 분에 시작, 707000 분에 종료
# 제품 그룹: 23D007-02
#   step1: 241000 분에 시작, 251100 분에 종료
#   step2: 254000 분에 시작, 266600 분에 종료
#   step3: 266600 분에 시작, 276900 분에 종료
#   step4: 276900 분에 시작, 285700 분에 종료
#   step5: 285700 분에 시작, 295400 분에 종료
#   step6: 299100 분에 시작, 313600 분에 종료
# 제품 그룹: 23D017-08
#   step1: 251100 분에 시작, 260500 분에 종료
#   step2: 266600 분에 시작, 277600 분에 종료
#   step3: 277600 분에 시작, 284700 분에 종료
#   step4: 284700 분에 시작, 296300 분에 종료
#   step5: 296300 분에 시작, 300600 분에 종료
#   step6: 313600 분에 시작, 328100 분에 종료
# 제품 그룹: 23E020-01
#   step1: 260500 분에 시작, 269300 분에 종료
#   step2: 277600 분에 시작, 290200 분에 종료
#   step3: 290200 분에 시작, 298500 분에 종료
#   step4: 298500 분에 시작, 309500 분에 종료
#   step5: 309500 분에 시작, 318500 분에 종료
#   step6: 328100 분에 시작, 343000 분에 종료
# 제품 그룹: 23C009-06
#   step1: 269300 분에 시작, 279100 분에 종료
#   step2: 290200 분에 시작, 300900 분에 종료
#   step3: 300900 분에 시작, 309700 분에 종료
#   step4: 309700 분에 시작, 321000 분에 종료
#   step5: 321000 분에 시작, 329200 분에 종료
#   step6: 1780700 분에 시작, 1801600 분에 종료
# 제품 그룹: 23Y016-02
#   step1: 279100 분에 시작, 287000 분에 종료
#   step2: 300900 분에 시작, 311300 분에 종료
#   step3: 311300 분에 시작, 322700 분에 종료
#   step4: 322700 분에 시작, 333000 분에 종료
#   step5: 333000 분에 시작, 342700 분에 종료
#   step6: 343000 분에 시작, 365200 분에 종료
# 제품 그룹: 23D018-01
#   step1: 287000 분에 시작, 296500 분에 종료
#   step2: 326100 분에 시작, 335800 분에 종료
#   step3: 335800 분에 시작, 344300 분에 종료
#   step4: 344300 분에 시작, 352200 분에 종료
#   step5: 353300 분에 시작, 364000 분에 종료
#   step6: 365200 분에 시작, 380200 분에 종료
# 제품 그룹: 23D024-04
#   step1: 296500 분에 시작, 309300 분에 종료
#   step2: 311300 분에 시작, 326100 분에 종료
#   step3: 326100 분에 시작, 335100 분에 종료
#   step4: 335100 분에 시작, 345300 분에 종료
#   step5: 345300 분에 시작, 353300 분에 종료
#   step6: 637700 분에 시작, 654800 분에 종료
# 제품 그룹: 23E012-03
#   step1: 309300 분에 시작, 320500 분에 종료
#   step2: 335800 분에 시작, 346500 분에 종료
#   step3: 346500 분에 시작, 356400 분에 종료
#   step4: 356400 분에 시작, 364500 분에 종료
#   step5: 364500 분에 시작, 370400 분에 종료
#   step6: 380200 분에 시작, 395500 분에 종료
# 제품 그룹: 23E017-08
#   step1: 320500 분에 시작, 332200 분에 종료
#   step2: 346500 분에 시작, 358800 분에 종료
#   step3: 358800 분에 시작, 367000 분에 종료
#   step4: 367000 분에 시작, 374800 분에 종료
#   step5: 374800 분에 시작, 393100 분에 종료
#   step6: 395500 분에 시작, 410900 분에 종료
# 제품 그룹: 23E008-01
#   step1: 332200 분에 시작, 339700 분에 종료
#   step2: 358800 분에 시작, 369100 분에 종료
#   step3: 369100 분에 시작, 379600 분에 종료
#   step4: 379600 분에 시작, 389900 분에 종료
#   step5: 402700 분에 시작, 412700 분에 종료
#   step6: 947900 분에 시작, 958900 분에 종료
# 제품 그룹: 23D023-03
#   step1: 339700 분에 시작, 354300 분에 종료
#   step2: 378200 분에 시작, 391400 분에 종료
#   step3: 391400 분에 시작, 400600 분에 종료
#   step4: 400600 분에 시작, 408300 분에 종료
#   step5: 412700 분에 시작, 421800 분에 종료
#   step6: 426400 분에 시작, 441900 분에 종료
# 제품 그룹: 23D023-01
#   step1: 354300 분에 시작, 362300 분에 종료
#   step2: 369100 분에 시작, 378200 분에 종료
#   step3: 378200 분에 시작, 387600 분에 종료
#   step4: 387600 분에 시작, 389400 분에 종료
#   step5: 393100 분에 시작, 402700 분에 종료
#   step6: 410900 분에 시작, 426400 분에 종료
# 제품 그룹: 23E029-03
#   step1: 362300 분에 시작, 376900 분에 종료
#   step2: 391400 분에 시작, 404600 분에 종료
#   step3: 404600 분에 시작, 411900 분에 종료
#   step4: 411900 분에 시작, 422100 분에 종료
#   step5: 422100 분에 시작, 430400 분에 종료
#   step6: 441900 분에 시작, 457500 분에 종료
# 제품 그룹: 23D024-05
#   step1: 376900 분에 시작, 398000 분에 종료
#   step2: 404600 분에 시작, 418900 분에 종료
#   step3: 418900 분에 시작, 429400 분에 종료
#   step4: 429400 분에 시작, 440100 분에 종료
#   step5: 440100 분에 시작, 450100 분에 종료
#   step6: 958900 분에 시작, 970700 분에 종료
# 제품 그룹: 23D017-24
#   step1: 398000 분에 시작, 408900 분에 종료
#   step2: 418900 분에 시작, 429900 분에 종료
#   step3: 429900 분에 시작, 441800 분에 종료
#   step4: 441800 분에 시작, 453400 분에 종료
#   step5: 453400 분에 시작, 453500 분에 종료
#   step6: 457500 분에 시작, 473100 분에 종료
# 제품 그룹: 23D018-03
#   step1: 408900 분에 시작, 417100 분에 종료
#   step2: 429900 분에 시작, 439300 분에 종료
#   step3: 439300 분에 시작, 449400 분에 종료
#   step4: 449400 분에 시작, 456000 분에 종료
#   step5: 456000 분에 시작, 465200 분에 종료
#   step6: 473100 분에 시작, 488800 분에 종료
# 제품 그룹: 23E007-01
#   step1: 417100 분에 시작, 425400 분에 종료
#   step2: 439300 분에 시작, 448600 분에 종료
#   step3: 448600 분에 시작, 457500 분에 종료
#   step4: 457500 분에 시작, 467900 분에 종료
#   step5: 467900 분에 시작, 478000 분에 종료
#   step6: 671900 분에 시작, 689400 분에 종료
# 제품 그룹: 23Y023-01
#   step1: 425400 분에 시작, 437000 분에 종료
#   step2: 733200 분에 시작, 744900 분에 종료
#   step3: 744900 분에 시작, 752200 분에 종료
#   step4: 752200 분에 시작, 761600 분에 종료
#   step5: 782500 분에 시작, 801000 분에 종료
#   step6: 937500 분에 시작, 947900 분에 종료
# 제품 그룹: 23Y023-03
#   step1: 437000 분에 시작, 444300 분에 종료
#   step2: 448600 분에 시작, 461000 분에 종료
#   step3: 461000 분에 시작, 471700 분에 종료
#   step4: 471700 분에 시작, 478300 분에 종료
#   step5: 478300 분에 시작, 485100 분에 종료
#   step6: 488800 분에 시작, 504900 분에 종료
# 제품 그룹: 23D013-01
#   step1: 444300 분에 시작, 453600 분에 종료
#   step2: 461000 분에 시작, 470400 분에 종료
#   step3: 470400 분에 시작, 478900 분에 종료
#   step4: 478900 분에 시작, 487500 분에 종료
#   step5: 487500 분에 시작, 497900 분에 종료
#   step6: 504900 분에 시작, 521100 분에 종료
# 제품 그룹: 23E029-02
#   step1: 453600 분에 시작, 463100 분에 종료
#   step2: 470400 분에 시작, 482100 분에 종료
#   step3: 482100 분에 시작, 488900 분에 종료
#   step4: 488900 분에 시작, 499800 분에 종료
#   step5: 552700 분에 시작, 562500 분에 종료
#   step6: 897200 분에 시작, 917100 분에 종료
# 제품 그룹: 23E012-04
#   step1: 463100 분에 시작, 471500 분에 종료
#   step2: 482100 분에 시작, 492200 분에 종료
#   step3: 492200 분에 시작, 496600 분에 종료
#   step4: 496600 분에 시작, 503400 분에 종료
#   step5: 503400 분에 시작, 511500 분에 종료
#   step6: 521100 분에 시작, 537300 분에 종료
# 제품 그룹: 23D021-27
#   step1: 471500 분에 시작, 481600 분에 종료
#   step2: 492200 분에 시작, 505500 분에 종료
#   step3: 505500 분에 시작, 513000 분에 종료
#   step4: 513000 분에 시작, 513900 분에 종료
#   step5: 513900 분에 시작, 533500 분에 종료
#   step6: 537300 분에 시작, 553600 분에 종료
# 제품 그룹: 23D021-05
#   step1: 481600 분에 시작, 490600 분에 종료
#   step2: 505500 분에 시작, 515300 분에 종료
#   step3: 515300 분에 시작, 526400 분에 종료
#   step4: 526400 분에 시작, 537100 분에 종료
#   step5: 537100 분에 시작, 552700 분에 종료
#   step6: 553600 분에 시작, 570100 분에 종료
# 제품 그룹: 23D017-20
#   step1: 490600 분에 시작, 504500 분에 종료
#   step2: 515300 분에 시작, 530200 분에 종료
#   step3: 530200 분에 시작, 541900 분에 종료
#   step4: 541900 분에 시작, 553600 분에 종료
#   step5: 562500 분에 시작, 562600 분에 종료
#   step6: 570100 분에 시작, 586800 분에 종료
# 제품 그룹: 23D016-02
#   step1: 504500 분에 시작, 518300 분에 종료
#   step2: 530200 분에 시작, 542900 분에 종료
#   step3: 542900 분에 시작, 558600 분에 종료
#   step4: 558600 분에 시작, 567500 분에 종료
#   step5: 567500 분에 시작, 579700 분에 종료
#   step6: 586800 분에 시작, 603700 분에 종료
# 제품 그룹: 23D017-19
#   step1: 518300 분에 시작, 529200 분에 종료
#   step2: 542900 분에 시작, 554900 분에 종료
#   step3: 554900 분에 시작, 566600 분에 종료
#   step4: 566600 분에 시작, 578400 분에 종료
#   step5: 589800 분에 시작, 590100 분에 종료
#   step6: 1459500 분에 시작, 1482100 분에 종료
# 제품 그룹: 23D026-01
#   step1: 529200 분에 시작, 537900 분에 종료
#   step2: 554900 분에 시작, 563500 분에 종료
#   step3: 563500 분에 시작, 569200 분에 종료
#   step4: 569200 분에 시작, 577700 분에 종료
#   step5: 579700 분에 시작, 589800 분에 종료
#   step6: 603700 분에 시작, 620700 분에 종료
# 제품 그룹: 23E017-06
#   step1: 537900 분에 시작, 550400 분에 종료
#   step2: 563500 분에 시작, 576000 분에 종료
#   step3: 576000 분에 시작, 585800 분에 종료
#   step4: 585800 분에 시작, 595100 분에 종료
#   step5: 595100 분에 시작, 611200 분에 종료
#   step6: 620700 분에 시작, 637700 분에 종료
# 제품 그룹: 23D027-01
#   step1: 550400 분에 시작, 557300 분에 종료
#   step2: 586400 분에 시작, 596300 분에 종료
#   step3: 596300 분에 시작, 607300 분에 종료
#   step4: 607300 분에 시작, 609100 분에 종료
#   step5: 620400 분에 시작, 636900 분에 종료
#   step6: 654800 분에 시작, 671900 분에 종료
# 제품 그룹: 23Y022-01
#   step1: 557300 분에 시작, 563800 분에 종료
#   step2: 614300 분에 시작, 624500 분에 종료
#   step3: 624500 분에 시작, 632600 분에 종료
#   step4: 632600 분에 시작, 644000 분에 종료
#   step5: 645200 분에 시작, 665900 분에 종료
#   step6: 707000 분에 시작, 724900 분에 종료
# 제품 그룹: 23D021-04
#   step1: 563800 분에 시작, 572400 분에 종료
#   step2: 576000 분에 시작, 586400 분에 종료
#   step3: 586400 분에 시작, 597600 분에 종료
#   step4: 597600 분에 시작, 607500 분에 종료
#   step5: 611200 분에 시작, 620400 분에 종료
#   step6: 1482100 분에 시작, 1497700 분에 종료
# 제품 그룹: 23D025-05
#   step1: 572400 분에 시작, 584300 분에 종료
#   step2: 624500 분에 시작, 636500 분에 종료
#   step3: 636500 분에 시작, 645400 분에 종료
#   step4: 645400 분에 시작, 654100 분에 종료
#   step5: 665900 분에 시작, 677000 분에 종료
#   step6: 742900 분에 시작, 761700 분에 종료
# 제품 그룹: 23E019-01
#   step1: 584300 분에 시작, 596400 분에 종료
#   step2: 636500 분에 시작, 648900 분에 종료
#   step3: 648900 분에 시작, 660700 분에 종료
#   step4: 660700 분에 시작, 669400 분에 종료
#   step5: 677000 분에 시작, 684800 분에 종료
#   step6: 761700 분에 시작, 780600 분에 종료
# 제품 그룹: 23B004-15
#   step1: 596400 분에 시작, 606800 분에 종료
#   step2: 648900 분에 시작, 660200 분에 종료
#   step3: 660200 분에 시작, 672300 분에 종료
#   step4: 672300 분에 시작, 683400 분에 종료
#   step5: 684800 분에 시작, 698000 분에 종료
#   step6: 780600 분에 시작, 799700 분에 종료
# 제품 그룹: 23E020-02
#   step1: 606800 분에 시작, 616000 분에 종료
#   step2: 660200 분에 시작, 673300 분에 종료
#   step3: 673300 분에 시작, 680400 분에 종료
#   step4: 680400 분에 시작, 692900 분에 종료
#   step5: 698000 분에 시작, 710600 분에 종료
#   step6: 799700 분에 시작, 818900 분에 종료
# 제품 그룹: 23Y019-04
#   step1: 616000 분에 시작, 628100 분에 종료
#   step2: 673300 분에 시작, 685000 분에 종료
#   step3: 685000 분에 시작, 697500 분에 종료
#   step4: 697500 분에 시작, 707600 분에 종료
#   step5: 710600 분에 시작, 717900 분에 종료
#   step6: 818900 분에 시작, 838100 분에 종료
# 제품 그룹: 23D025-03
#   step1: 628100 분에 시작, 641700 분에 종료
#   step2: 685000 분에 시작, 697200 분에 종료
#   step3: 697200 분에 시작, 699000 분에 종료
#   step4: 699000 분에 시작, 706900 분에 종료
#   step5: 717900 분에 시작, 735500 분에 종료
#   step6: 838100 분에 시작, 857500 분에 종료
# 제품 그룹: 23D004-02
#   step1: 641700 분에 시작, 654300 분에 종료
#   step2: 697200 분에 시작, 709700 분에 종료
#   step3: 709700 분에 시작, 720700 분에 종료
#   step4: 720700 분에 시작, 727700 분에 종료
#   step5: 735500 분에 시작, 749000 분에 종료
#   step6: 857500 분에 시작, 877300 분에 종료
# 제품 그룹: 23D023-06
#   step1: 654300 분에 시작, 669400 분에 종료
#   step2: 709700 분에 시작, 723200 분에 종료
#   step3: 723200 분에 시작, 731900 분에 종료
#   step4: 731900 분에 시작, 740600 분에 종료
#   step5: 749000 분에 시작, 759700 분에 종료
#   step6: 877300 분에 시작, 897200 분에 종료
# 제품 그룹: 23D024-02
#   step1: 669400 분에 시작, 678200 분에 종료
#   step2: 723200 분에 시작, 733200 분에 종료
#   step3: 733200 분에 시작, 745600 분에 종료
#   step4: 745600 분에 시작, 754300 분에 종료
#   step5: 759700 분에 시작, 782500 분에 종료
#   step6: 917100 분에 시작, 937500 분에 종료
# 제품 그룹: 23Y019-03
#   step1: 678200 분에 시작, 686800 분에 종료
#   step2: 744900 분에 시작, 756700 분에 종료
#   step3: 756700 분에 시작, 764100 분에 종료
#   step4: 764100 분에 시작, 772400 분에 종료
#   step5: 801000 분에 시작, 807300 분에 종료
#   step6: 981700 분에 시작, 1436500 분에 종료
# 제품 그룹: 23D021-23
#   step1: 686800 분에 시작, 698800 분에 종료
#   step2: 756700 분에 시작, 768000 분에 종료
#   step3: 768000 분에 시작, 778400 분에 종료
#   step4: 778400 분에 시작, 788500 분에 종료
#   step5: 807300 분에 시작, 825600 분에 종료
#   step6: 1738600 분에 시작, 1759800 분에 종료
# 제품 그룹: 23A029-19
#   step1: 698800 분에 시작, 709500 분에 종료
#   step2: 768000 분에 시작, 779500 분에 종료
#   step3: 779500 분에 시작, 789900 분에 종료
#   step4: 789900 분에 시작, 800200 분에 종료
#   step5: 859200 분에 시작, 875700 분에 종료
#   step6: 1609100 분에 시작, 1630900 분에 종료
# 제품 그룹: 23D016-03
#   step1: 709500 분에 시작, 723900 분에 종료
#   step2: 811200 분에 시작, 823700 분에 종료
#   step3: 823700 분에 시작, 830400 분에 종료
#   step4: 830400 분에 시작, 842100 분에 종료
#   step5: 923500 분에 시작, 937400 분에 종료
#   step6: 1695900 분에 시작, 1717400 분에 종료
# 제품 그룹: 23D021-11
#   step1: 723900 분에 시작, 734800 분에 종료
#   step2: 779500 분에 시작, 791800 분에 종료
#   step3: 791800 분에 시작, 798400 분에 종료
#   step4: 798400 분에 시작, 810100 분에 종료
#   step5: 825600 분에 시작, 840900 분에 종료
#   step6: 1436500 분에 시작, 1459500 분에 종료
# 제품 그룹: 23D016-06
#   step1: 734800 분에 시작, 748400 분에 종료
#   step2: 844900 분에 시작, 857400 분에 종료
#   step3: 857400 분에 시작, 868300 분에 종료
#   step4: 868300 분에 시작, 876000 분에 종료
#   step5: 967400 분에 시작, 979500 분에 종료
#   step6: 1717400 분에 시작, 1738600 분에 종료
# 제품 그룹: 23D013-02
#   step1: 748400 분에 시작, 759500 분에 종료
#   step2: 823700 분에 시작, 834900 분에 종료
#   step3: 834900 분에 시작, 844400 분에 종료
#   step4: 844400 분에 시작, 853100 분에 종료
#   step5: 893200 분에 시작, 909500 분에 종료
#   step6: 1876500 분에 시작, 1897000 분에 종료
# 제품 그룹: 23E003-01
#   step1: 759500 분에 시작, 768200 분에 종료
#   step2: 791800 분에 시작, 801200 분에 종료
#   step3: 801200 분에 시작, 811700 분에 종료
#   step4: 811700 분에 시작, 821700 분에 종료
#   step5: 875700 분에 시작, 893200 분에 종료
#   step6: 1855800 분에 시작, 1876500 분에 종료
# 제품 그룹: 23D024-01
#   step1: 768200 분에 시작, 777200 분에 종료
#   step2: 801200 분에 시작, 811200 분에 종료
#   step3: 811200 분에 시작, 819300 분에 종료
#   step4: 819300 분에 시작, 829700 분에 종료
#   step5: 840900 분에 시작, 859200 분에 종료
#   step6: 1759800 분에 시작, 1780700 분에 종료
# 제품 그룹: 23D024-03
#   step1: 777200 분에 시작, 787600 분에 종료
#   step2: 887800 분에 시작, 899900 분에 종료
#   step3: 899900 분에 시작, 907200 분에 종료
#   step4: 907200 분에 시작, 918400 분에 종료
#   step5: 990900 분에 시작, 1001000 분에 종료
#   step6: 1520300 분에 시작, 1542800 분에 종료
# 제품 그룹: 23D020-03
#   step1: 787600 분에 시작, 797600 분에 종료
#   step2: 857400 분에 시작, 867400 분에 종료
#   step3: 867400 분에 시작, 876600 분에 종료
#   step4: 876600 분에 시작, 888000 분에 종료
#   step5: 979600 분에 시작, 990900 분에 종료
#   step6: 1674300 분에 시작, 1695900 분에 종료
# 제품 그룹: 23D021-25
#   step1: 797600 분에 시작, 805300 분에 종료
#   step2: 834900 분에 시작, 844900 분에 종료
#   step3: 844900 분에 시작, 858500 분에 종료
#   step4: 858500 분에 시작, 872100 분에 종료
#   step5: 1039000 분에 시작, 1044700 분에 종료
#   step6: 1565100 분에 시작, 1587300 분에 종료
# 제품 그룹: 23D017-06
#   step1: 805300 분에 시작, 816100 분에 종료
#   step2: 917000 분에 시작, 928000 분에 종료
#   step3: 928000 분에 시작, 941400 분에 종료
#   step4: 941400 분에 시작, 952100 분에 종료
#   step5: 1044700 분에 시작, 1048500 분에 종료
#   step6: 1497700 분에 시작, 1520300 분에 종료
# 제품 그룹: 23D020-04
#   step1: 816100 분에 시작, 824500 분에 종료
#   step2: 877300 분에 시작, 887800 분에 종료
#   step3: 887800 분에 시작, 899300 분에 종료
#   step4: 899300 분에 시작, 910700 분에 종료
#   step5: 1030800 분에 시작, 1039000 분에 종료
#   step6: 1630900 분에 시작, 1652700 분에 종료
# 제품 그룹: 23D025-01
#   step1: 824500 분에 시작, 834300 분에 종료
#   step2: 909100 분에 시작, 917000 분에 종료
#   step3: 917000 분에 시작, 923500 분에 종료
#   step4: 923500 분에 시작, 933700 분에 종료
#   step5: 937400 분에 시작, 953400 분에 종료
#   step6: 1801600 분에 시작, 1822500 분에 종료
# 제품 그룹: 23A012-04
#   step1: 834300 분에 시작, 843200 분에 종료
#   step2: 899900 분에 시작, 909100 분에 종료
#   step3: 909100 분에 시작, 919700 분에 종료
#   step4: 919700 분에 시작, 930200 분에 종료
#   step5: 1001000 분에 시작, 1012400 분에 종료
#   step6: 1897000 분에 시작, 1917500 분에 종료
# 제품 그룹: 23A012-01
#   step1: 843200 분에 시작, 852900 분에 종료
#   step2: 928000 분에 시작, 938200 분에 종료
#   step3: 938200 분에 시작, 948800 분에 종료
#   step4: 948800 분에 시작, 953000 분에 종료
#   step5: 953400 분에 시작, 967400 분에 종료
#   step6: 1542800 분에 시작, 1565100 분에 종료
# 제품 그룹: 23D017-31
#   step1: 852900 분에 시작, 861400 분에 종료
#   step2: 947600 분에 시작, 957500 분에 종료
#   step3: 957500 분에 시작, 963500 분에 종료
#   step4: 963500 분에 시작, 977300 분에 종료
#   step5: 979500 분에 시작, 979600 분에 종료
#   step6: 1917500 분에 시작, 1926600 분에 종료
# 제품 그룹: 23Y020-04
#   step1: 861400 분에 시작, 866800 분에 종료
#   step2: 867400 분에 시작, 877300 분에 종료
#   step3: 877300 분에 시작, 887800 분에 종료
#   step4: 887800 분에 시작, 897200 분에 종료
#   step5: 909500 분에 시작, 923500 분에 종료
#   step6: 1652700 분에 시작, 1674300 분에 종료
# 제품 그룹: 23D017-42
#   step1: 866800 분에 시작, 877000 분에 종료
#   step2: 938200 분에 시작, 947600 분에 종료
#   step3: 947600 분에 시작, 958100 분에 종료
#   step4: 958100 분에 시작, 968200 분에 종료
#   step5: 1022200 분에 시작, 1030800 분에 종료
#   step6: 1587300 분에 시작, 1609100 분에 종료
# 제품 그룹: 23D018-09
#   step1: 877000 분에 시작, 888000 분에 종료
#   step2: 957500 분에 시작, 965300 분에 종료
#   step3: 965300 분에 시작, 975400 분에 종료
#   step4: 975400 분에 시작, 985700 분에 종료
#   step5: 1012400 분에 시작, 1022200 분에 종료
#   step6: 1835000 분에 시작, 1855800 분에 종료

# %%
# 코드스니펫
"""
'step1 작업 시간(분)', 'step2 작업 시간(분)',
         'step3 작업 시간(분)', 'step4 작업 시간(분)',
         'step5 작업 시간(분)', 'step6 작업 시간(분)'

for idx, row in df.iterrows():
    product_group = row['제품군']
    processing_times = {
        'step1': int(round(row['step1 최종 작업 시간'] * SCALE)),
        'step2': int(round(row['step2 최종 작업 시간'] * SCALE)),
        'step3': int(round(row['step3 최종 작업 시간'] * SCALE)),
        'step4': int(round(row['step4 최종 작업 시간'] * SCALE)),
        'step5': int(round(row['step5 최종 작업 시간'] * SCALE)),
        'step6': int(round(row['step6 최종 작업 시간'] * SCALE)),
    }
    units.append({
        'unit_id': f"{product_group}",
        'product_group': product_group,
        'processing_times': processing_times,
    })
